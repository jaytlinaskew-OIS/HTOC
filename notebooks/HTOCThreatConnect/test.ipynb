# %%
from HTOCThreatConnect import get_v3_threatconnect_data

# %%
df = get_v3_threatconnect_data(lastObserved_date='2023-01-01', indicatorActive=False, bothActivities=True)
display(df)
# Out:
#                     id             dateAdded  ownerId ownerName  \
# 0     5629499567007562  2025-09-05T13:32:42Z        9  HTOC Org
# 1     5629499537002037  2025-04-20T17:12:37Z        9  HTOC Org
# 2              5271607  2025-01-29T16:27:10Z        9  HTOC Org
# 3     6755399442005033  2025-02-12T20:12:22Z        9  HTOC Org
# 4     5629499535005059  2025-02-12T20:09:47Z        9  HTOC Org
# ...                ...                   ...      ...       ...
# 3631            223630  2016-12-13T19:56:35Z        9  HTOC Org
# 3632            223570  2016-12-13T19:56:35Z        9  HTOC Org
# 3633           4312413  2023-03-27T12:00:37Z        9  HTOC Org
# 3634           4307013  2023-03-12T12:00:16Z        9  HTOC Org
# 3635            223610  2016-12-13T19:56:35Z        9  HTOC Org
#
#                                                 webLink     type  \
# 0     https://hvs.threatconnect.com/#/details/indica...     Host
# ...

# %%
from HTOCThreatConnect import get_v2_threatconnect_data

# %%
df = get_v2_threatconnect_data(dateObserved=None)
display(df)
# Out:
# [DEBUG] status=200
# [DEBUG] Retrieved 776 observed indicators for HTOC Org on 2025-11-18
#      observationCount          lastObserved  \
# 0             7402732  2025-11-18T13:03:51Z
# 1             1820026  2025-11-18T13:43:13Z
# 2             1641032  2025-11-18T13:03:52Z
# 3             1494011  2025-11-18T13:43:13Z
# 4              462623  2025-11-18T13:31:06Z
# ..                ...                   ...
# 771                 1  2025-11-18T07:03:36Z
# 772                 1  2025-11-18T10:38:06Z
# 773                 1  2025-11-18T11:33:20Z
# 774                 1  2025-11-18T09:08:04Z
# 775                 1  2025-11-18T07:31:45Z
#
#                                       userObservedList       indicator
# 0    [{'userName': '35664937356778434955', 'fullNam...   79.124.49.226
# 1    [{'userName': '35664937356778434955', 'fullNam...   91.191.209.74
# 2    [{'userName': '35664937356778434955', 'fullNam...  91.191.209.198
# ...
