# %%
from HTOCThreatConnect import get_v3_threatconnect_data

# %%
df = get_v3_threatconnect_data(lastObserved_date=None)
display(df)
# Out:
#                     id             dateAdded  ownerId ownerName  \
# 0     6755399448005420  2025-05-19T11:57:28Z        9  HTOC Org
# 1     6755399459033753  2025-06-16T17:42:36Z        9  HTOC Org
# 2     6755399460000259  2025-06-27T18:49:59Z        9  HTOC Org
# 3     6755399459078661  2025-06-25T17:45:55Z        9  HTOC Org
# 4     6755399459078654  2025-06-25T17:45:52Z        9  HTOC Org
# ...                ...                   ...      ...       ...
# 3683            223630  2016-12-13T19:56:35Z        9  HTOC Org
# 3684            223570  2016-12-13T19:56:35Z        9  HTOC Org
# 3685           4312413  2023-03-27T12:00:37Z        9  HTOC Org
# 3686           4307013  2023-03-12T12:00:16Z        9  HTOC Org
# 3687            223610  2016-12-13T19:56:35Z        9  HTOC Org
#
#                                                 webLink     type  \
# 0     https://hvs.threatconnect.com/#/details/indica...  Address
# 1     https://hvs.threatconnect.com/#/details/indica...  Address
# 2     https://hvs.threatconnect.com/#/details/indica...  Address
# 3     https://hvs.threatconnect.com/#/details/indica...  Address
# 4     https://hvs.threatconnect.com/#/details/indica...  Address
# ...                                                 ...      ...
# 3683  https://hvs.threatconnect.com/#/details/indica...      URL
# 3684  https://hvs.threatconnect.com/#/details/indica...      URL
# 3685  https://hvs.threatconnect.com/#/details/indica...     File
# 3686  https://hvs.threatconnect.com/#/details/indica...     File
# 3687  https://hvs.threatconnect.com/#/details/indica...      URL
#
#               lastModified  rating  confidence  \
# 0     2025-09-30T13:06:52Z     1.0        36.0
# 1     2025-09-30T12:57:10Z     3.0        65.0
# 2     2025-09-30T12:56:59Z     3.0        67.0
# 3     2025-09-30T12:56:04Z     3.0        71.0
# 4     2025-09-30T12:56:04Z     3.0        67.0
# ...                    ...     ...         ...
# 3683  2023-05-18T20:50:10Z     3.0        89.0
# 3684  2023-03-31T18:50:10Z     3.0        89.0
# 3685  2023-03-28T12:00:42Z     5.0       100.0
# 3686  2023-03-12T12:00:26Z     5.0       100.0
# 3687  2022-08-12T15:50:16Z     3.0        89.0
#
#                                             description  ...  active  \
# 0     IP 51.158.205.47 is associated with a moderate...  ...    True
# 1                                           RITM0589984  ...    True
# 2                                            INC9123318  ...    True
# 3                                           TASK0902923  ...    True
# 4                                           TASK0891295  ...    True
# ...                                                 ...  ...     ...
# 3683  HTTP Referer sending victims to exploit kit la...  ...    True
# 3684  HTTP Referer sending victims to exploit kit la...  ...    True
# 3685  File IOCs observed targeting HHS via malspam c...  ...    True
# 3686  Malicious File Hash Indicators and Malspam inf...  ...    True
# 3687  HTTP Referer sending victims to exploit kit la...  ...    True
#
#       activeLocked                                         legacyLink  \
# 0            False  https://hvs.threatconnect.com/auth/indicators/...
# 1            False  https://hvs.threatconnect.com/auth/indicators/...
# 2            False  https://hvs.threatconnect.com/auth/indicators/...
# 3            False  https://hvs.threatconnect.com/auth/indicators/...
# 4            False  https://hvs.threatconnect.com/auth/indicators/...
# ...            ...                                                ...
# 3683         False  https://hvs.threatconnect.com/auth/indicators/...
# 3684         False  https://hvs.threatconnect.com/auth/indicators/...
# 3685         False  https://hvs.threatconnect.com/auth/indicators/...
# 3686         False  https://hvs.threatconnect.com/auth/indicators/...
# 3687         False  https://hvs.threatconnect.com/auth/indicators/...
#
#                                               tags.data  \
# 0     [{'id': 1707683, 'name': 'The Netherlands', 'l...
# 1     [{'id': 35760, 'name': 'OS Splunk API', 'descr...
# 2     [{'id': 471298, 'name': 'DHA Splunk API', 'las...
# 3     [{'id': 471298, 'name': 'DHA Splunk API', 'las...
# 4     [{'id': 471298, 'name': 'DHA Splunk API', 'las...
# ...                                                 ...
# 3683  [{'id': 23769, 'name': 'VA CSOC CTS Splunk', '...
# 3684  [{'id': 23769, 'name': 'VA CSOC CTS Splunk', '...
# 3685  [{'id': 35367, 'name': 'hhs-2023032801', 'last...
# 3686  [{'id': 35156, 'name': 'hhs-2023031201', 'last...
# 3687  [{'id': 23769, 'name': 'VA CSOC CTS Splunk', '...
#
#                                   associatedGroups.data dnsActive whoisActive  \
# 0                                                   NaN       NaN         NaN
# 1                                                   NaN       NaN         NaN
# 2                                                   NaN       NaN         NaN
# 3                                                   NaN       NaN         NaN
# 4                                                   NaN       NaN         NaN
# ...                                                 ...       ...         ...
# 3683  [{'id': 39224, 'dateAdded': '2016-12-13T17:57:...       NaN         NaN
# 3684  [{'id': 39224, 'dateAdded': '2016-12-13T17:57:...       NaN         NaN
# 3685  [{'id': 149124, 'dateAdded': '2023-03-27T12:00...       NaN         NaN
# 3686  [{'id': 148462, 'dateAdded': '2023-03-12T12:00...       NaN         NaN
# 3687  [{'id': 39224, 'dateAdded': '2016-12-13T17:57:...       NaN         NaN
#
#                    source      size  \
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2                     NaN       NaN
# 3                     NaN       NaN
# 4                     NaN       NaN
# ...                   ...       ...
# 3683                  NaN       NaN
# 3684                  NaN       NaN
# 3685  API ingestion - R&F  327719.0
# 3686  API ingestion - R&F  808599.0
# 3687                  NaN       NaN
#
#                                             indicator
# 0                                       51.158.205.47
# 1                                       195.47.238.84
# 2                                        45.78.224.98
# 3                                         65.49.1.103
# 4                                       64.62.156.231
# ...                                               ...
# 3683                           http://www.zenpad.org/
# 3684  http://www.fultonarts.org/index.php/art-centers
# 3685                 913283BB9EB72DFAD5005436B07BBD38
# 3686                 FD1390C116CE2AEB7F41F4841A8898A7
# 3687  http://www.southhillsortho.com/contact/contact/
#
# [3688 rows x 21 columns]

# %%
from HTOCThreatConnect import get_v2_threatconnect_data

# %%
df = get_v2_threatconnect_data(lastObserved_date=None)
display(df)
