# %%
from HTOCThreatConnect import get_v3_threatconnect_data

# %%
df = get_v3_threatconnect_data(lastObserved_date='2025-01-01', indicatorActive=False)
display(df)
# Out:
#                    id             dateAdded  ownerId ownerName  \
# 0    6755399443033831  2025-04-11T17:46:49Z        9  HTOC Org
# 1    5629499566201482  2025-09-03T14:54:47Z        9  HTOC Org
# 2    6755399443033495  2025-04-11T17:27:17Z        9  HTOC Org
# 3             4808308  2024-08-07T15:39:11Z        9  HTOC Org
# 4             4329688  2023-05-05T13:15:25Z        9  HTOC Org
# ..                ...                   ...      ...       ...
# 946           4403362  2023-09-17T13:21:38Z        9  HTOC Org
# 947           4299533  2023-02-15T15:04:33Z        9  HTOC Org
# 948           4319206  2023-04-10T14:30:12Z        9  HTOC Org
# 949           4720935  2024-06-17T18:11:00Z        9  HTOC Org
# 950           4402865  2023-09-15T19:51:29Z        9  HTOC Org
#
#                                                webLink     type  \
# 0    https://hvs.threatconnect.com/#/details/indica...  Address
# 1    https://hvs.threatconnect.com/#/details/indica...  Address
# 2    https://hvs.threatconnect.com/#/details/indica...  Address
# 3    https://hvs.threatconnect.com/#/details/indica...  Address
# 4    https://hvs.threatconnect.com/#/details/indica...  Address
# ..                                                 ...      ...
# 946  https://hvs.threatconnect.com/#/details/indica...     Host
# 947  https://hvs.threatconnect.com/#/details/indica...  Address
# 948  https://hvs.threatconnect.com/#/details/indica...  Address
# 949  https://hvs.threatconnect.com/#/details/indica...  Address
# 950  https://hvs.threatconnect.com/#/details/indica...  Address
#
#              lastModified  rating  confidence  \
# 0    2025-10-14T16:14:24Z     4.0        65.0
# 1    2025-10-14T15:13:47Z     3.0        75.0
# 2    2025-10-14T14:14:09Z     1.0        46.0
# 3    2025-10-14T10:53:35Z     4.0        43.0
# 4    2025-10-14T10:53:30Z     1.0         5.0
# ..                    ...     ...         ...
# 946  2025-03-09T08:32:14Z     3.0         0.0
# 947  2025-03-06T08:31:22Z     4.0         0.0
# 948  2025-02-22T07:16:02Z     3.0         0.0
# 949  2025-02-12T07:16:09Z     1.0         0.0
# 950  2025-01-23T07:36:38Z     3.0         0.0
#
#                                            description  privateFlag  active  \
# 0    (U//FOUO) Federal law enforcement and the Inte...        False   False
# 1                                           INC9219946        False   False
# 2    Executive Summary:  \n\nThe following IP addre...        False   False
# 3    BugSleep is a custom backdoor Muddy Water has ...        False   False
# 4    https://socradar.io/dark-web-profile-blackcat-...        False   False
# ..                                                 ...          ...     ...
# 946                                                NaN        False   False
# 947  These are socgholish cases or fake update.  Wi...        False   False
# 948  The Cybersecurity and Infrastructure Security ...        False   False
# 949  **(U//FOUO) Additional Indicators of Compromis...        False   False
# 950  A malvertising campaign is targeting corporate...        False   False
#
#      activeLocked                                         legacyLink  \
# 0           False  https://hvs.threatconnect.com/auth/indicators/...
# 1           False  https://hvs.threatconnect.com/auth/indicators/...
# 2           False  https://hvs.threatconnect.com/auth/indicators/...
# 3           False  https://hvs.threatconnect.com/auth/indicators/...
# 4           False  https://hvs.threatconnect.com/auth/indicators/...
# ..            ...                                                ...
# 946         False  https://hvs.threatconnect.com/auth/indicators/...
# 947         False  https://hvs.threatconnect.com/auth/indicators/...
# 948         False  https://hvs.threatconnect.com/auth/indicators/...
# 949         False  https://hvs.threatconnect.com/auth/indicators/...
# 950         False  https://hvs.threatconnect.com/auth/indicators/...
#
#                                              tags.data  \
# 0    [{'id': 471298, 'name': 'DHA Splunk API', 'las...
# 1    [{'id': 35760, 'name': 'OS Splunk API', 'descr...
# 2    [{'id': 1707685, 'name': 'Bulgaria', 'lastUsed...
# 3    [{'id': 471298, 'name': 'DHA Splunk API', 'las...
# 4    [{'id': 1466757, 'name': 'BlackCat', 'lastUsed...
# ..                                                 ...
# 946  [{'id': 39761, 'name': 'darkgate', 'lastUsed':...
# 947  [{'id': 39624, 'name': 'HHS Splunk Production ...
# 948  [{'id': 35760, 'name': 'OS Splunk API', 'descr...
# 949  [{'id': 275467, 'name': 'Cyber Intelligence Ne...
# 950  [{'id': 39704, 'name': 'Antivirus evasion', 'l...
#
#                                  associatedGroups.data source dnsActive  \
# 0    [{'id': 6755399443004631, 'dateAdded': '2025-0...    NaN       NaN
# 1                                                  NaN    NaN       NaN
# 2    [{'id': 6755399444000503, 'dateAdded': '2025-0...    NaN       NaN
# 3    [{'id': 454519, 'dateAdded': '2024-09-04T15:06...    NaN       NaN
# 4    [{'id': 150524, 'dateAdded': '2023-05-05T13:13...    NaN       NaN
# ..                                                 ...    ...       ...
# 946  [{'id': 162887, 'dateAdded': '2023-09-17T13:20...    NaN     False
# 947  [{'id': 138694, 'dateAdded': '2022-07-12T00:01...    NaN       NaN
# 948  [{'id': 150135, 'dateAdded': '2023-04-25T18:20...    NaN       NaN
# 949  [{'id': 345639, 'dateAdded': '2024-06-17T17:59...    NaN       NaN
# 950  [{'id': 162660, 'dateAdded': '2023-09-15T19:51...    NaN       NaN
#
#     whoisActive        indicator
# 0           NaN     194.26.29.44
# 1           NaN    141.98.10.225
# 2           NaN    194.180.49.70
# 3           NaN    31.171.154.54
# 4           NaN    23.216.147.76
# ..          ...              ...
# 946       False  www.zerofox.com
# 947         NaN  173.254.104.138
# 948         NaN      79.98.104.4
# 949         NaN   205.169.39.195
# 950         NaN    31.31.196.208
#
# [951 rows x 20 columns]

# %%
from HTOCThreatConnect import get_v2_threatconnect_data

# %%
df = get_v2_threatconnect_data()
display(df)
# Out:
# [DEBUG] status=200
# [DEBUG] Retrieved 774 observed indicators for HTOC Org on 2025-09-30
#      observationCount          lastObserved  \
# 0             4045310  2025-09-30T14:04:26Z
# 1             3164958  2025-09-30T14:03:46Z
# 2             1653203  2025-09-30T14:04:33Z
# 3              628265  2025-09-30T07:33:19Z
# 4              613522  2025-09-30T07:33:58Z
# ..                ...                   ...
# 769                 1  2025-09-30T10:00:57Z
# 770                 1  2025-09-30T05:34:41Z
# 771                 1  2025-09-30T13:32:00Z
# 772                 1  2025-09-30T05:31:26Z
# 773                 1  2025-09-30T01:31:19Z
#
#                                       userObservedList        indicator
# 0    [{'userName': '13520457953477229971', 'fullNam...   78.128.113.190
# 1    [{'userName': '13520457953477229971', 'fullNam...    45.142.193.49
# 2    [{'userName': '64853912235916233429', 'fullNam...     5.188.206.46
# 3    [{'userName': '13520457953477229971', 'fullNam...  172.232.188.177
# 4    [{'userName': '50189120947314147395', 'fullNam...   66.175.208.166
# ..                                                 ...              ...
# 769  [{'userName': '64853912235916233429', 'fullNam...    45.84.107.222
# 770  [{'userName': '74198686107399967946', 'fullNam...    brppharma.com
# 771  [{'userName': '74198686107399967946', 'fullNam...   academy4sc.org
# 772  [{'userName': '13520457953477229971', 'fullNam...   104.244.73.193
# 773  [{'userName': '13520457953477229971', 'fullNam...    27.43.207.128
#
# [774 rows x 4 columns]
