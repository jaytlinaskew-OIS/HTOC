# %%
import os
import pandas as pd

folder_path = r"Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Full Daily Reports"
files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
files
# Out:
# ['full_daily_report_20250616.csv',
#  'full_daily_report_20250617.csv',
#  'full_daily_report_20250618.csv',
#  'full_daily_report_20250623.csv',
#  'full_daily_report_20250624.csv',
#  'full_daily_report_20250625.csv',
#  'full_daily_report_20250626.csv',
#  'full_daily_report_20250627.csv',
#  'full_daily_report_20250630.csv',
#  'full_daily_report_20250701.csv',
#  'full_daily_report_20250702.csv',
#  'full_daily_report_20250703.csv',
#  'full_daily_report_20250707.csv',
#  'full_daily_report_20250708.csv',
#  'full_daily_report_20250709.csv',
#  'full_daily_report_20250710.csv',
#  'full_daily_report_20250711.csv',
#  'full_daily_report_20250714.csv',
#  'full_daily_report_20250715.csv',
#  'full_daily_report_20250716.csv',
#  'full_daily_report_20250717.csv',
#  'full_daily_report_20250718.csv',
#  'full_daily_report_20250721.csv',
#  'full_daily_report_20250722.csv',
#  'full_daily_report_20250723.csv',
#  'full_daily_report_20250724.csv',
#  'full_daily_report_20250725.csv',
#  'full_daily_report_20250728.csv']

# %%
from datetime import datetime

# Get today's date in the same format as the file names (YYYYMMDD)
today_str = datetime.now().strftime('%Y%m%d')

# Filter files that contain today's date
current_date_files = [f for f in files if today_str in f]
current_date_files
# Out:
# ['full_daily_report_20250728.csv']

# %%
dfs = {}
for file_name in files:
    file_path = os.path.join(folder_path, file_name)
    var_name = os.path.splitext(file_name)[0]  # Remove .csv extension
    dfs[var_name] = pd.read_csv(file_path)
    print(f"Loaded {file_name} into dfs['{var_name}'], shape: {dfs[var_name].shape}")

# Example of accessing a specific DataFrame
df_example = dfs['full_daily_report_20250616']
# Out:
# Loaded full_daily_report_20250616.csv into dfs['full_daily_report_20250616'], shape: (6395, 12)
# Loaded full_daily_report_20250617.csv into dfs['full_daily_report_20250617'], shape: (6751, 12)
# Loaded full_daily_report_20250618.csv into dfs['full_daily_report_20250618'], shape: (7082, 12)
# Loaded full_daily_report_20250623.csv into dfs['full_daily_report_20250623'], shape: (7408, 12)
# Loaded full_daily_report_20250624.csv into dfs['full_daily_report_20250624'], shape: (7509, 12)
# Loaded full_daily_report_20250625.csv into dfs['full_daily_report_20250625'], shape: (7533, 12)
# Loaded full_daily_report_20250626.csv into dfs['full_daily_report_20250626'], shape: (8007, 12)
# Loaded full_daily_report_20250627.csv into dfs['full_daily_report_20250627'], shape: (8433, 12)
# Loaded full_daily_report_20250630.csv into dfs['full_daily_report_20250630'], shape: (8514, 12)
# Loaded full_daily_report_20250701.csv into dfs['full_daily_report_20250701'], shape: (9050, 12)
# Loaded full_daily_report_20250702.csv into dfs['full_daily_report_20250702'], shape: (9243, 12)
# Loaded full_daily_report_20250703.csv into dfs['full_daily_report_20250703'], shape: (9450, 12)
# Loaded full_daily_report_20250707.csv into dfs['full_daily_report_20250707'], shape: (9810, 12)
# Loaded full_daily_report_20250708.csv into dfs['full_daily_report_20250708'], shape: (9861, 12)
# Loaded full_daily_report_20250709.csv into dfs['full_daily_report_20250709'], shape: (9901, 12)
# Loaded full_daily_report_20250710.csv into dfs['full_daily_report_20250710'], shape: (9969, 12)
# Loaded full_daily_report_20250711.csv into dfs['full_daily_report_20250711'], shape: (10020, 12)
# Loaded full_daily_report_20250714.csv into dfs['full_daily_report_20250714'], shape: (10252, 12)
# Loaded full_daily_report_20250715.csv into dfs['full_daily_report_20250715'], shape: (10284, 12)
# Loaded full_daily_report_20250716.csv into dfs['full_daily_report_20250716'], shape: (10340, 12)
# Loaded full_daily_report_20250717.csv into dfs['full_daily_report_20250717'], shape: (10370, 12)
# Loaded full_daily_report_20250718.csv into dfs['full_daily_report_20250718'], shape: (2591, 12)
# Loaded full_daily_report_20250721.csv into dfs['full_daily_report_20250721'], shape: (10468, 12)
# Loaded full_daily_report_20250722.csv into dfs['full_daily_report_20250722'], shape: (10546, 12)
# Loaded full_daily_report_20250723.csv into dfs['full_daily_report_20250723'], shape: (8595, 12)
# Loaded full_daily_report_20250724.csv into dfs['full_daily_report_20250724'], shape: (5251, 12)
# Loaded full_daily_report_20250725.csv into dfs['full_daily_report_20250725'], shape: (8621, 12)
# Loaded full_daily_report_20250728.csv into dfs['full_daily_report_20250728'], shape: (8980, 12)

# %%
display(df_example.head())
# Out:
#          Indicator  Observed Today  Frequency (7d)  Frequency (30d)  \
# 0  102.129.153.158               0             0.0              1.0
# 1   102.129.153.43               0             0.0              0.0
# 2   102.129.153.71               0             0.0              2.0
# 3   102.165.16.161               0             0.0              0.0
# 4   103.133.107.28               0             0.0              1.0
#
#   Probability: 7-Day      Confidence: 7-Day Probability: 14-Day  \
# 0              6.88%  7-Day: Low confidence              13.68%
# 1              0.38%  7-Day: Low confidence               0.93%
# 2             12.39%  7-Day: Low confidence               24.8%
# 3              0.01%  7-Day: Low confidence               0.01%
# 4              9.14%  7-Day: Low confidence              59.14%
#
#         Confidence: 14-Day Probability: 30-Day       Confidence: 30-Day  \
# 0   14-Day: Low confidence              68.66%  30-Day: Possibly active
# 1   14-Day: Low confidence              18.11%   30-Day: Low confidence
# 2   14-Day: Low confidence              86.71%    30-Day: Highly likely
# 3   14-Day: Low confidence               0.17%   30-Day: Low confidence
# 4  14-Day: Possibly active              73.35%  30-Day: Possibly active
#
#   Partner  FileDate
# 0     CDC  20250616
# 1     CDC  20250616
# 2     CDC  20250616
# 3     CDC  20250616
# 4     CDC  20250616

# %%
# List all subfolders in folder_path
logs_folder = r'Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs'

subfolders = [f.path for f in os.scandir(logs_folder) if f.is_dir()]
for subfolder in subfolders:
    print(f"Folder: {os.path.basename(subfolder)}")
    subfolder_files = [f for f in os.listdir(subfolder) if os.path.isfile(os.path.join(subfolder, f))]
    print(f"  Files: {subfolder_files}")
# Out:
# Folder: CDC
#   Files: ['CDC_forecast_log.xlsx', 'forecast_log.xlsx', '~$forecast_log_2025-06-23.xlsx']
# Folder: CMS
#   Files: ['CMS_forecast_log.xlsx', 'forecast_log.xlsx']
# Folder: DHA
#   Files: ['DHA_forecast_log.xlsx', 'forecast_log.xlsx']
# Folder: FDA
#   Files: ['FDA_forecast_log.xlsx', 'forecast_log.xlsx']
# Folder: HHS
#   Files: ['forecast_log.xlsx', 'HHS_forecast_log.xlsx']
# Folder: HRSA
#   Files: ['forecast_log.xlsx', 'HRSA_forecast_log.xlsx']
# Folder: IHS
#   Files: ['forecast_log.xlsx', 'IHS_forecast_log.xlsx']
# Folder: NIH
#   Files: ['forecast_log.xlsx', 'NIH_forecast_log.xlsx']
# Folder: OS
#   Files: ['forecast_log.xlsx', 'OS_forecast_log.xlsx']
# Folder: VA
#   Files: ['forecast_log.xlsx', 'VA_forecast_log.xlsx']

# %%
excel_dfs = {}
for subfolder in subfolders:
    subfolder_files = [f for f in os.listdir(subfolder) if os.path.isfile(os.path.join(subfolder, f))]
    for file in subfolder_files:
        # Skip temporary Excel files (usually start with '~$')
        if file.endswith('.xlsx') and not file.startswith('~$'):
            file_full_path = os.path.join(subfolder, file)
            var_base = os.path.splitext(file)[0]
            excel_dfs[var_base] = pd.read_excel(file_full_path, engine='openpyxl')
            print(f"Loaded {file} from {os.path.basename(subfolder)} into excel_dfs['{var_base}'], shape: {excel_dfs[var_base].shape}")
# Out:
# Loaded CDC_forecast_log.xlsx from CDC into excel_dfs['CDC_forecast_log'], shape: (37659, 6)
# Loaded forecast_log.xlsx from CDC into excel_dfs['forecast_log'], shape: (34500, 6)
# Loaded CMS_forecast_log.xlsx from CMS into excel_dfs['CMS_forecast_log'], shape: (123216, 6)
# Loaded forecast_log.xlsx from CMS into excel_dfs['forecast_log'], shape: (112308, 6)
# Loaded DHA_forecast_log.xlsx from DHA into excel_dfs['DHA_forecast_log'], shape: (100101, 6)
# Loaded forecast_log.xlsx from DHA into excel_dfs['forecast_log'], shape: (90870, 6)
# Loaded FDA_forecast_log.xlsx from FDA into excel_dfs['FDA_forecast_log'], shape: (92484, 6)
# Loaded forecast_log.xlsx from FDA into excel_dfs['forecast_log'], shape: (83781, 6)
# Loaded forecast_log.xlsx from HHS into excel_dfs['forecast_log'], shape: (22326, 6)
# Loaded HHS_forecast_log.xlsx from HHS into excel_dfs['HHS_forecast_log'], shape: (26085, 6)
# Loaded forecast_log.xlsx from HRSA into excel_dfs['forecast_log'], shape: (59601, 6)
# Loaded HRSA_forecast_log.xlsx from HRSA into excel_dfs['HRSA_forecast_log'], shape: (64635, 6)
# Loaded forecast_log.xlsx from IHS into excel_dfs['forecast_log'], shape: (73668, 6)
# Loaded IHS_forecast_log.xlsx from IHS into excel_dfs['IHS_forecast_log'], shape: (81393, 6)
# Loaded forecast_log.xlsx from NIH into excel_dfs['forecast_log'], shape: (116757, 6)
# Loaded NIH_forecast_log.xlsx from NIH into excel_dfs['NIH_forecast_log'], shape: (127032, 6)
# Loaded forecast_log.xlsx from OS into excel_dfs['forecast_log'], shape: (75867, 6)
# Loaded OS_forecast_log.xlsx from OS into excel_dfs['OS_forecast_log'], shape: (84543, 6)
# Loaded forecast_log.xlsx from VA into excel_dfs['forecast_log'], shape: (95481, 6)
# Loaded VA_forecast_log.xlsx from VA into excel_dfs['VA_forecast_log'], shape: (106413, 6)

# %%
display(excel_dfs['VA_forecast_log'].head())
# Out:
#          Indicator Forecast Date Forecast Type       Confidence  \
# 0  1-you.njalla.no    2025-06-16        14-Day  Possibly active
# 1  1-you.njalla.no    2025-06-16        30-Day  Possibly active
# 2  1-you.njalla.no    2025-06-16         7-Day   Low confidence
# 3  1-you.njalla.no    2025-06-17        14-Day  Possibly active
# 4  1-you.njalla.no    2025-06-17        30-Day  Possibly active
#
#   Forecasted Check Date   Outcome
# 0            2025-06-30  Not Seen
# 1            2025-07-16   Pending
# 2            2025-06-23  Not Seen
# 3            2025-07-01   Pending
# 4            2025-07-17   Pending

# %%
import os
import shutil
from datetime import datetime
from typing import Dict
import pandas as pd
from IPython.display import display
from concurrent.futures import ThreadPoolExecutor

# ---------------------------------------------------------------------
# Normalize helper
CONFIDENCE_MAP = {
    '30-day: highly likely': 'Highly Likely',
    '30-day: possibly active': 'Possibly Active',
    '30-day: low confidence': 'Low Confidence',
    '14-day: highly likely': 'Highly Likely',
    '14-day: possibly active': 'Possibly Active',
    '14-day: low confidence': 'Low Confidence',
    '7-day: highly likely': 'Highly Likely',
    '7-day: possibly active': 'Possibly Active',
    '7-day: low confidence': 'Low Confidence',
    'highly likely': 'Highly Likely',
    'possibly active': 'Possibly Active',
    'low confidence': 'Low Confidence'
}

# ---------------------------------------------------------------------
# Normalize daily reports by FileDate
dfs_by_date: Dict[pd.Timestamp, pd.DataFrame] = {}
print("\n✅ Daily files successfully parsed by FileDate:")
for key, df in dfs.items():
    df.columns = df.columns.str.strip()
    if 'FileDate' not in df.columns:
        continue
    df = df.copy()
    df['FileDate'] = pd.to_datetime(df['FileDate'], errors='coerce').dt.normalize()
    valid_dates = df['FileDate'].dropna().unique()
    if valid_dates.size > 0:
        dfs[key] = df
        dfs_by_date.update({dt: df for dt in valid_dates})
        print(f"- {key} → {[d.strftime('%Y-%m-%d') for d in valid_dates]}")

# ---------------------------------------------------------------------
# Backup and clean forecast logs
backup_folder = r'Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup'
os.makedirs(backup_folder, exist_ok=True)
print("\n🔄 Backing up and cleaning existing forecast logs...")

def backup_and_clean_logs(subfolder):
    partner_name = os.path.basename(subfolder).strip()
    log_path = os.path.join(subfolder, "forecast_log.xlsx")
    if os.path.exists(log_path):
        backup_path = os.path.join(backup_folder, f"{partner_name}_forecast_log_backup_{datetime.now().strftime('%Y%m%d_%H%M%S')}.xlsx")
        shutil.copy2(log_path, backup_path)
        print(f"  Backed up {partner_name} → {backup_path}")
        os.remove(log_path)
        print(f"   Deleted original {partner_name} log")

with ThreadPoolExecutor() as executor:
    executor.map(backup_and_clean_logs, subfolders)

print("\n" + "="*60)
print(" Starting fresh data processing with clean normalization...")
print("="*60)

# ---------------------------------------------------------------------
# Process forecast logs per partner
def process_partner_logs(subfolder):
    partner_name = os.path.basename(subfolder).strip()
    partner_clean = partner_name.lower()
    log_key = f"{partner_name}_forecast_log"
    log_path = os.path.join(subfolder, "forecast_log.xlsx")
    if log_key not in excel_dfs:
        print(f" Skipping {partner_name}: No forecast log found.")
        return
    log_df = excel_dfs[log_key].copy()
    log_df.columns = log_df.columns.str.strip()
    log_df['Forecasted Check Date'] = pd.to_datetime(log_df['Forecasted Check Date'], errors='coerce').dt.normalize()
    log_df['Outcome'] = log_df.get('Outcome', '')
    log_df['Indicator_norm'] = log_df['Indicator'].astype(str).str.strip().str.lower()
    log_df['Confidence'] = log_df['Confidence'].astype(str).str.strip().str.lower().map(CONFIDENCE_MAP).fillna(log_df['Confidence'])
    log_df['Forecast Type'] = log_df['Forecast Type'].astype(str).str.split(':').str[-1].str.strip().str.title()
    if 'Indicator_norm' not in dfs_by_date:
        dfs_by_date['Indicator_norm'] = dfs_by_date['Indicator'].astype(str).str.strip().str.lower()
    if 'Partner_norm' not in dfs_by_date:
        dfs_by_date['Partner_norm'] = dfs_by_date['Partner'].astype(str).str.strip().str.lower()
    log_df['Outcome'] = log_df.apply(lambda row: 'Seen' if dfs_by_date.get(row['Forecasted Check Date'], pd.DataFrame()).query("Partner_norm == @partner_clean and Indicator_norm == @row['Indicator_norm']").get('Observed Today', pd.Series()).eq(1).any() else 'Not Seen', axis=1)
    print(f"\n {partner_name} – Outcome counts:")
    print(log_df['Outcome'].value_counts(dropna=False).to_string())
    display(log_df[log_df['Outcome'] == 'Seen'].head(50))
    if os.path.exists(log_path):
        try:
            existing_df = pd.read_excel(log_path)
            existing_df.columns = existing_df.columns.str.strip()
            existing_df['Confidence'] = existing_df['Confidence'].astype(str).str.strip().str.lower().map(CONFIDENCE_MAP).fillna(existing_df['Confidence'])
            existing_df['Forecast Type'] = existing_df['Forecast Type'].astype(str).str.split(':').str[-1].str.strip().str.title()
        except Exception as e:
            print(f" Could not read existing file for {partner_name}: {e}")
            existing_df = pd.DataFrame(columns=log_df.columns)
    else:
        existing_df = pd.DataFrame(columns=log_df.columns)
    combined_df = pd.concat([existing_df, log_df], ignore_index=True)
    combined_df['Forecast Date'] = pd.to_datetime(combined_df['Forecast Date'], errors='coerce')
    combined_df['Confidence'] = combined_df['Confidence'].astype(str).str.strip().str.lower().map(CONFIDENCE_MAP).fillna(combined_df['Confidence'])
    combined_df['Forecast Type'] = combined_df['Forecast Type'].astype(str).str.split(':').str[-1].str.strip().str.title()
    combined_df.drop_duplicates(subset=['Indicator', 'Forecast Date', 'Forecast Type', 'Confidence'], keep='last', inplace=True)
    combined_df.sort_values(by=['Indicator', 'Forecasted Check Date'], inplace=True)
    combined_df.drop(columns='Indicator_norm', inplace=True, errors='ignore')
    try:
        combined_df.to_excel(log_path, index=False)
        print(f" Updated and saved: {log_path}")
    except Exception as e:
        print(f" Failed to save log for {partner_name}: {e}")

with ThreadPoolExecutor() as executor:
    executor.map(process_partner_logs, subfolders)
# Out:
# ✅ Daily files successfully parsed by FileDate:
# - full_daily_report_20250616 → ['2025-06-16']
# - full_daily_report_20250617 → ['2025-06-17']
# - full_daily_report_20250618 → ['2025-06-18']
# - full_daily_report_20250623 → ['2025-06-23']
# - full_daily_report_20250624 → ['2025-06-24']
# - full_daily_report_20250625 → ['2025-06-25']
# - full_daily_report_20250626 → ['2025-06-26']
# - full_daily_report_20250627 → ['2025-06-27']
# - full_daily_report_20250630 → ['2025-06-30']
# - full_daily_report_20250701 → ['2025-07-01']
# - full_daily_report_20250702 → ['2025-07-02']
# - full_daily_report_20250703 → ['2025-07-03']
# - full_daily_report_20250707 → ['2025-07-07']
# - full_daily_report_20250708 → ['2025-07-08']
# - full_daily_report_20250709 → ['2025-07-09']
# - full_daily_report_20250710 → ['2025-07-10']
# - full_daily_report_20250711 → ['2025-07-11']
# - full_daily_report_20250714 → ['2025-07-14']
# - full_daily_report_20250715 → ['2025-07-15']
# - full_daily_report_20250716 → ['2025-07-16']
# - full_daily_report_20250717 → ['2025-07-17']
# - full_daily_report_20250718 → ['2025-07-18']
# - full_daily_report_20250721 → ['2025-07-21']
# - full_daily_report_20250722 → ['2025-07-22']
# - full_daily_report_20250723 → ['2025-07-23']
# - full_daily_report_20250724 → ['2025-07-24']
# - full_daily_report_20250725 → ['2025-07-25']
# - full_daily_report_20250728 → ['2025-07-28']
#
# 🔄 Backing up and cleaning existing forecast logs...
#   Backed up CDC → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\CDC_forecast_log_backup_20250728_090652.xlsx
#    Deleted original CDC log
#   Backed up CMS → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\CMS_forecast_log_backup_20250728_090653.xlsx
#    Deleted original CMS log
#   Backed up DHA → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\DHA_forecast_log_backup_20250728_090653.xlsx
#    Deleted original DHA log
#   Backed up FDA → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\FDA_forecast_log_backup_20250728_090653.xlsx
#    Deleted original FDA log
#   Backed up HHS → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\HHS_forecast_log_backup_20250728_090653.xlsx
#    Deleted original HHS log
#   Backed up HRSA → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\HRSA_forecast_log_backup_20250728_090653.xlsx
#    Deleted original HRSA log
#   Backed up IHS → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\IHS_forecast_log_backup_20250728_090653.xlsx
#    Deleted original IHS log
#   Backed up NIH → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\NIH_forecast_log_backup_20250728_090653.xlsx
#    Deleted original NIH log
#   Backed up OS → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\OS_forecast_log_backup_20250728_090653.xlsx
#    Deleted original OS log
#   Backed up VA → Z:\HTOC\Data_Analytics\Data\OpDiv_Predictions\Logs_Backup\VA_forecast_log_backup_20250728_090653.xlsx
#    Deleted original VA log
#
# ============================================================
#  Starting fresh data processing with clean normalization...
# ============================================================
#
#  CDC – Outcome counts:
