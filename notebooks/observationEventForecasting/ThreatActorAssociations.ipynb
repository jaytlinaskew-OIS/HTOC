# %%
import pandas as pd
THREAT_ACTORS = r'Z:\HTOC\Data_Analytics\Data\Observed_Tags\htoc_observed_indicator_tags.csv'
production_output = pd.read_csv(r'C:\Users\jaskew\Documents\project_repository\notebooks\observationEventForecasting\production_output.csv')

# %%
# Load threat actor tag data from the specified CSV file
threat_actor_tags = pd.read_csv(THREAT_ACTORS)
display(threat_actor_tags)
# Out:
#                    indicator          type  \
# 0     003@tagmode-search.com  EmailAddress
# 1                 0secure.ru          Host
# 2                 0secure.ru          Host
# 3            1-you.njalla.no          Host
# 4            1-you.njalla.no          Host
# ...                      ...           ...
# 8997             zerocap.com          Host
# 8998             zerocap.com          Host
# 8999     zimbra@infinigi.com  EmailAddress
# 9000     zimbra@infinigi.com  EmailAddress
# 9001     zimbra@infinigi.com  EmailAddress
#
#                                             tag  threat_category
# 0                                       Malspam        TECHNIQUE
# 1                                Reconnaissance        TECHNIQUE
# 2                                      Phishing  MITRE_TECHNIQUE
# 3                                       Malspam        TECHNIQUE
# 4                                 CVE-2017-0199    VULNERABILITY
# ...                                         ...              ...
# 8997                                 SocGholish          MALWARE
# 8998  Ransomware/Ransomware-as-a-Service (RaaS)     MALWARE TYPE
# 8999                                Health-ISAC           SOURCE
# 9000                                   Phishing  MITRE_TECHNIQUE
# 9001                                Agent Tesla          MALWARE
#
# [9002 rows x 4 columns]

# %%
# Extract a list of unique threat actor tags from threat_actor_tags
threat_actor_tag_list = threat_actor_tags[
    threat_actor_tags['threat_category'].str.contains('THREAT ACTOR', case=False, na=False)
]['tag'].unique().tolist()
threat_actor_tag_list
# Out:
# ['Wicked Panda',
#  'Refined Kitten',
#  'Rocket Kitten',
#  'Cozy Bear',
#  'UNC5537',
#  'ShadowSyndicate',
#  'thedarkoverlord',
#  'UNC4841',
#  'UNC5807',
#  'Fancy Bear',
#  'Primitive Bear',
#  'Volt Typhoon',
#  'Seashell Blizzard',
#  'Star Blizzard',
#  'Scattered Spider',
#  'Morphing Meerkat',
#  'UNC3973',
#  'Mustang Panda',
#  'Indrik Spider',
#  'Pay-Per-Install Service',
#  'Mustard Tempest',
#  'Initial Access Broker',
#  'Cold River',
#  'Static Kitten',
#  'UNC5439',
#  'UNC5221',
#  'Charming Kitten',
#  'Play Ransomware Group',
#  'storm-0558',
#  'UNC5266',
#  'Lace Tempest',
#  'ALPHV',
#  'UNC4936',
#  'Flax Typhoon',
#  'Storm-1849',
#  'Venomous Bear',
#  'Unc5175',
#  'Unc5435',
#  'UNC5435',
#  'UNC5175',
#  'Velvet Chollima',
#  'Machete',
#  '8220 Gang',
#  'UNC3313',
#  'UNC4487',
#  'UNC1714',
#  'Kryptonite Panda',
#  'Prophet Spider',
#  'storm-0494',
#  'Affiliates',
#  'UNC5837',
#  'Carbon Spider',
#  'Strawberry Tempest',
#  'noname(057)16',
#  'Storm-0866',
#  'UAT-4820',
#  'LilacSquid',
#  'LABRAT',
#  'TA582',
#  'Asylum Ambuscade',
#  'Rhysida',
#  'Storm-2077',
#  'TAG-100',
#  'UNC4509',
#  'Deep Panda',
#  'UNC4536',
#  'Apothecary Spider',
#  'Storm-1113',
#  'UNC5174',
#  'Helix Kitten',
#  'Unfurling Hemlock',
#  'UNC4698',
#  'UNC3594',
#  'Crystalray',
#  'Ghostwriter',
#  'UNC1151',
#  'TA577',
#  'Circuit Panda',
#  'Anchor Panda',
#  'UNC3953',
#  'Boriselchin',
#  'Unc4681',
#  'UNC4899',
#  'TA578',
#  'Dynamite Panda',
#  'Hippo Team',
#  'Revolver Rabbit',
#  'Stardust Chollima',
#  'UNC5148',
#  'XeGroup']

# %%
matched_indicators = production_output['Indicator'].isin(threat_actor_tags['indicator'])
production_output_with_tags = production_output[matched_indicators]
# Merge in tags and threat categories from threat_actor_tags
production_output_with_tags = production_output_with_tags.merge(
    threat_actor_tags[['indicator', 'tag', 'threat_category']],
    left_on='Indicator',
    right_on='indicator',
    how='left'
)

display(production_output_with_tags)
# Out:
#              Indicator  Observed Today  Frequency (7d)  Frequency (30d)  \
# 0       103.108.231.67               0             0.0              1.0
# 1      103.149.249.226               0             0.0              0.0
# 2      103.149.249.226               0             0.0              0.0
# 3        103.77.192.88               0             0.0              1.0
# 4        103.77.192.88               0             0.0              1.0
# ...                ...             ...             ...              ...
# 1625  www.filemail.com               0             0.0              2.0
# 1626  www.filemail.com               0             0.0              2.0
# 1627  www.filemail.com               0             0.0              2.0
# 1628  www.filemail.com               0             0.0              2.0
# 1629  www.filemail.com               0             0.0              2.0
#
#      Probability: Today      Confidence: Today Probability: 7-Day  \
# 0                 0.05%  Today: Low confidence              6.45%
# 1                  0.0%  Today: Low confidence              0.07%
# 2                  0.0%  Today: Low confidence              0.07%
# 3                  0.3%  Today: Low confidence              7.53%
# 4                  0.3%  Today: Low confidence              7.53%
# ...                 ...                    ...                ...
# 1625              1.21%  Today: Low confidence             25.39%
# 1626              1.21%  Today: Low confidence             25.39%
# 1627              1.21%  Today: Low confidence             25.39%
# 1628              1.21%  Today: Low confidence             25.39%
# 1629              1.21%  Today: Low confidence             25.39%
#
#           Confidence: 7-Day Probability: 14-Day      Confidence: 14-Day  \
# 0     7-Day: Low confidence              11.71%  14-Day: Low confidence
# 1     7-Day: Low confidence               0.31%  14-Day: Low confidence
# 2     7-Day: Low confidence               0.31%  14-Day: Low confidence
# 3     7-Day: Low confidence              16.44%  14-Day: Low confidence
# 4     7-Day: Low confidence              16.44%  14-Day: Low confidence
# ...                     ...                 ...                     ...
# 1625  7-Day: Low confidence              90.04%  14-Day: Low confidence
# 1626  7-Day: Low confidence              90.04%  14-Day: Low confidence
# 1627  7-Day: Low confidence              90.04%  14-Day: Low confidence
# 1628  7-Day: Low confidence              90.04%  14-Day: Low confidence
# 1629  7-Day: Low confidence              90.04%  14-Day: Low confidence
#
#      Probability: 30-Day      Confidence: 30-Day         indicator  \
# 0                 42.21%  30-Day: Low confidence    103.108.231.67
# 1                  2.32%  30-Day: Low confidence   103.149.249.226
# 683    43.225.189.132               0             2.0             12.0
# 684    43.225.189.163               0             0.0              9.0
# 687    45.134.140.131               0             0.0              3.0
# 688     45.134.212.80               0             0.0              2.0
# 689      45.134.79.98               0             0.0              1.0
# 725     46.19.136.227               0             0.0              2.0
# 1193    79.127.217.35               0             0.0              1.0
# 1290      93.115.0.49               0             1.0              1.0
#
#      Probability: Today       Confidence: Today Probability: 7-Day  \
# 0                 0.05%   Today: Low confidence              6.45%
# 25                0.02%   Today: Low confidence              0.44%
# 68                3.67%   Today: Low confidence             30.56%
# 69                 0.0%   Today: Low confidence              0.01%
# 91                0.16%   Today: Low confidence             18.34%
# 112              72.82%    Today: Highly likely             94.89%
# 120               2.65%   Today: Low confidence             15.41%
# 121                0.0%   Today: Low confidence              0.02%
# 123              15.36%  Today: Possibly active             98.11%
# 131               0.05%   Today: Low confidence             12.97%
# 133               10.1%  Today: Possibly active             56.59%
# 141               10.1%  Today: Possibly active             56.59%
# 143               8.96%  Today: Possibly active              90.3%
# 151               0.13%   Today: Low confidence              6.82%
# 153              13.16%  Today: Possibly active             83.81%
# 165               0.04%   Today: Low confidence              6.41%
# 166              15.65%  Today: Possibly active             100.0%
# 176               0.01%   Today: Low confidence              0.04%
# 177               0.01%   Today: Low confidence              0.03%
# 178               0.01%   Today: Low confidence              0.02%
# 193              22.04%  Today: Possibly active             88.91%
# 202              25.09%  Today: Possibly active             82.81%
# 321               4.43%   Today: Low confidence             88.89%
# 324              33.95%  Today: Possibly active             100.0%
# 437               6.78%   Today: Low confidence             88.92%
# 445               1.79%   Today: Low confidence             12.99%
# 446               0.04%   Today: Low confidence              6.41%
# 449              72.82%    Today: Highly likely             94.89%
# 476               9.69%  Today: Possibly active              85.9%
# 522               2.65%   Today: Low confidence             15.41%
# 530               1.79%   Today: Low confidence             12.99%
# 537               0.01%   Today: Low confidence              0.04%
# 546               0.06%   Today: Low confidence               6.5%
# 555                0.0%   Today: Low confidence              0.02%
# 564               0.04%   Today: Low confidence              6.41%
# 593              24.32%  Today: Possibly active             91.47%
# 601               0.37%   Today: Low confidence             21.14%
# 602               0.01%   Today: Low confidence              0.44%
# 603               0.01%   Today: Low confidence              0.03%
# 637               1.48%   Today: Low confidence             37.23%
# 677               0.02%   Today: Low confidence              12.2%
# 681               0.35%   Today: Low confidence             24.06%
# 683               5.38%   Today: Low confidence             100.0%
# 684               0.76%   Today: Low confidence             43.54%
# 687               0.21%   Today: Low confidence             18.29%
# 688               1.47%   Today: Low confidence             27.09%
# 689               0.07%   Today: Low confidence              7.48%
# 725               0.64%   Today: Low confidence             22.26%
# 1193              0.29%   Today: Low confidence              9.64%
# 1290             20.06%  Today: Possibly active             59.05%
#
#            Confidence: 7-Day Probability: 14-Day       Confidence: 14-Day  \
# 0      7-Day: Low confidence              11.71%   14-Day: Low confidence
# 25     7-Day: Low confidence               2.17%   14-Day: Low confidence
# 68     7-Day: Low confidence              99.32%   14-Day: Low confidence
# 69     7-Day: Low confidence               0.01%   14-Day: Low confidence
# 689               59.97%   30-Day: Low confidence     45.134.79.98  UNC5537
# 725               100.0%   30-Day: Low confidence    46.19.136.227  UNC5537
# 1193              70.32%   30-Day: Low confidence    79.127.217.35  UNC5537
# 1290              74.92%  30-Day: Possibly active      93.115.0.49  UNC5537
#
#      threat_category
# 0       THREAT ACTOR
# 25      THREAT ACTOR
# 68      THREAT ACTOR
# 69      THREAT ACTOR
# 91      THREAT ACTOR
# 112     THREAT ACTOR
# 120     THREAT ACTOR
# 121     THREAT ACTOR
# 123     THREAT ACTOR
# 131     THREAT ACTOR
# 133     THREAT ACTOR
# 141     THREAT ACTOR
# 143     THREAT ACTOR
# 151     THREAT ACTOR
# 153     THREAT ACTOR
# 165     THREAT ACTOR
# 166     THREAT ACTOR
# 176     THREAT ACTOR
# 177     THREAT ACTOR
# 178     THREAT ACTOR
# 193     THREAT ACTOR
# 202     THREAT ACTOR
# 321     THREAT ACTOR
# 324     THREAT ACTOR
# 437     THREAT ACTOR
# 445     THREAT ACTOR
# 446     THREAT ACTOR
# 449     THREAT ACTOR
# 476     THREAT ACTOR
# 522     THREAT ACTOR
# 530     THREAT ACTOR
# 537     THREAT ACTOR
# 546     THREAT ACTOR
# 555     THREAT ACTOR
# 564     THREAT ACTOR
# 593     THREAT ACTOR
# 601     THREAT ACTOR
# 602     THREAT ACTOR
# 603     THREAT ACTOR
# 637     THREAT ACTOR
# 677     THREAT ACTOR
# 681     THREAT ACTOR
# 683     THREAT ACTOR
# 684     THREAT ACTOR
# 687     THREAT ACTOR
# 688     THREAT ACTOR
# 689     THREAT ACTOR
# 725     THREAT ACTOR
# 1193    THREAT ACTOR
# 1290    THREAT ACTOR

# %%
# Condense tags for each indicator into a single row with lists of tags and threat categories
condensed = (
    production_output_with_tags
    .groupby('Indicator')
    .agg({
        'Observed Today': 'first',
        'Frequency (7d)': 'first',
        'Frequency (30d)': 'first',
        'Probability: Today': 'first',
        'Confidence: Today': 'first',
        'Probability: 7-Day': 'first',
        'Confidence: 7-Day': 'first',
        'Probability: 14-Day': 'first',
        'Confidence: 14-Day': 'first',
        'Probability: 30-Day': 'first',
        'Confidence: 30-Day': 'first',
        'tag': lambda x: list(x.unique()),
        'threat_category': lambda x: list(x.dropna().unique())
    })
    .reset_index()
)

display(condensed)
# Out:
#                                Indicator  Observed Today  Frequency (7d)  \
# 0                         103.108.231.67               0             0.0
# 1                        103.149.249.226               0             0.0
# 2                          103.77.192.88               0             0.0
# 3                        104.128.161.233               0             6.0
# 4                         104.129.24.124               0             0.0
# ..                                   ...             ...             ...
# 299                            vtext.com               1             7.0
# 300                        ws.onehub.com               0             2.0
# 301                           www.3u.com               0             0.0
# 302  www.deepseek.com.cdn.cloudflare.net               0             5.0
# 303                     www.filemail.com               0             0.0
#
#      Frequency (30d) Probability: Today       Confidence: Today  \
# 0                1.0              0.05%   Today: Low confidence
# 1                0.0               0.0%   Today: Low confidence
# 2                1.0               0.3%   Today: Low confidence
# 3               29.0             82.29%    Today: Highly likely
# 4                0.0              0.02%   Today: Low confidence
# ..               ...                ...                     ...
# 299             30.0             80.96%    Today: Highly likely
# 300              5.0             19.06%  Today: Possibly active
# 301              0.0               0.0%   Today: Low confidence
# 302             23.0             47.34%  Today: Possibly active
# 303              2.0              1.21%   Today: Low confidence
#
#     Probability: 7-Day      Confidence: 7-Day Probability: 14-Day  \
# 0                6.45%  7-Day: Low confidence              11.71%
# 1                0.07%  7-Day: Low confidence               0.31%
# 2                7.53%  7-Day: Low confidence              16.44%
# 3               100.0%   7-Day: Highly likely              100.0%
# 4                0.44%  7-Day: Low confidence               2.17%
# ..                 ...                    ...                 ...
# 299             100.0%   7-Day: Highly likely              100.0%
# 300             98.76%   7-Day: Highly likely              100.0%
# 301               0.0%  7-Day: Low confidence                0.0%
# 302             100.0%   7-Day: Highly likely              100.0%
# 303             25.39%  7-Day: Low confidence              90.04%
#
#          Confidence: 14-Day Probability: 30-Day      Confidence: 30-Day  \
# 0    14-Day: Low confidence              42.21%  30-Day: Low confidence
# 1    14-Day: Low confidence               2.32%  30-Day: Low confidence
# 2    14-Day: Low confidence              47.96%  30-Day: Low confidence
# 3     14-Day: Highly likely              100.0%   30-Day: Highly likely
# 4    14-Day: Low confidence              11.21%  30-Day: Low confidence
# ..                      ...                 ...                     ...
# 299   14-Day: Highly likely              100.0%   30-Day: Highly likely
# 300   14-Day: Highly likely              100.0%   30-Day: Highly likely
# 301  14-Day: Low confidence               0.52%  30-Day: Low confidence
# 302   14-Day: Highly likely              100.0%   30-Day: Highly likely
# 303  14-Day: Low confidence              100.0%  30-Day: Low confidence
#
#                                                    tag  \
# 0                                            [UNC5537]
# 1                            [CVE-2024-4040, CrushFTP]
# 2    [ghostloot, UNC5807, Reconnaissance, STOWAWAY,...
# 3    [Cozy Bear, Fancy Bear, GRU, GRIZZLY STEPPE, G...
# 4    [Snowflake, UNC5537, Credential theft, Informa...
# ..                                                 ...
# 299                     [Phishing, Gootloader Malware]
# 300  [SyncroMSP, Unified Endpoint Management, Stati...
# 301                                       [multiverze]
# 302                                         [DeepSeek]
# 303  [SyncroMSP, Unified Endpoint Management, Stati...
#
#                                        threat_category
# 0                                       [THREAT ACTOR]
# 1                                      [VULNERABILITY]
# 2    [MALWARE, THREAT ACTOR, TECHNIQUE, MITRE_TECHN...
# 3    [THREAT ACTOR, SPONSOR ORGANIZATION, CAMPAIGN,...
# 4    [VULNERABILITY, THREAT ACTOR, TECHNIQUE, SECTO...
# ..                                                 ...
# 299                         [MITRE_TECHNIQUE, MALWARE]
# 300  [THREAT ACTOR, MALWARE, TECHNIQUE, SPONSOR ORG...
# 301                                                 []
# 302                                    [VULNERABILITY]
# 303  [THREAT ACTOR, TECHNIQUE, SPONSOR ORGANIZATION...
#
# [304 rows x 14 columns]

# %%
filtered_df = condensed[condensed['tag'].apply(lambda tags: any(tag in threat_actor_tag_list for tag in tags))].copy()

# Create column of related threat actor
filtered_df.loc[:, 'related_threat_actors'] = filtered_df['tag'].apply(
    lambda tags: [tag for tag in tags if tag in threat_actor_tag_list]
)
filtered_df = filtered_df.drop(columns=['tag', 'threat_category'])
display(filtered_df)
# Out:
#                Indicator  Observed Today  Frequency (7d)  Frequency (30d)  \
# 0         103.108.231.67               0             0.0              1.0
# 2          103.77.192.88               0             0.0              1.0
# 3        104.128.161.233               0             6.0             29.0
# 4         104.129.24.124               0             0.0              0.0
# 5         104.16.230.132               0             0.0              1.0
# ..                   ...             ...             ...              ...
# 290    prosinthecity.com               0             0.0              1.0
# 291       r3.o.lencr.org               0             0.0              2.0
# 294  summerwaterhall.com               0             0.0              2.0
# 300        ws.onehub.com               0             2.0              5.0
# 303     www.filemail.com               0             0.0              2.0
#
#     Probability: Today       Confidence: Today Probability: 7-Day  \
# 0                0.05%   Today: Low confidence              6.45%
# 2                 0.3%   Today: Low confidence              7.53%
# 3               82.29%    Today: Highly likely             100.0%
# 4                0.02%   Today: Low confidence              0.44%
# 5                0.07%   Today: Low confidence              6.55%
# ..                 ...                     ...                ...
# 290              0.06%   Today: Low confidence               6.5%
# 291               0.4%   Today: Low confidence             15.36%
# 294              0.35%   Today: Low confidence             18.52%
# 300             19.06%  Today: Possibly active             98.76%
# 303              1.21%   Today: Low confidence             25.39%
#
#          Confidence: 7-Day Probability: 14-Day      Confidence: 14-Day  \
# 0    7-Day: Low confidence              11.71%  14-Day: Low confidence
# 2    7-Day: Low confidence              16.44%  14-Day: Low confidence
# 3     7-Day: Highly likely              100.0%   14-Day: Highly likely
# 4    7-Day: Low confidence               2.17%  14-Day: Low confidence
# 5    7-Day: Low confidence              12.08%  14-Day: Low confidence
# ..                     ...                 ...                     ...
# 290  7-Day: Low confidence              11.87%  14-Day: Low confidence
# 291  7-Day: Low confidence              43.71%  14-Day: Low confidence
# 294  7-Day: Low confidence              51.37%  14-Day: Low confidence
# 300   7-Day: Highly likely              100.0%   14-Day: Highly likely
# 303  7-Day: Low confidence              90.04%  14-Day: Low confidence
#
#     Probability: 30-Day      Confidence: 30-Day          related_threat_actors
# 0                42.21%  30-Day: Low confidence                      [UNC5537]
# 2                47.96%  30-Day: Low confidence             [UNC5807, UNC4841]
# 3                100.0%   30-Day: Highly likely        [Cozy Bear, Fancy Bear]
# 4                11.21%  30-Day: Low confidence                      [UNC5537]
# 5                44.33%  30-Day: Low confidence               [Primitive Bear]
# ..                  ...                     ...                            ...
# 290              43.34%  30-Day: Low confidence              [Mustard Tempest]
# 291              78.95%  30-Day: Low confidence              [Mustard Tempest]
# 294              80.32%  30-Day: Low confidence                    [Cozy Bear]
# 300              100.0%   30-Day: Highly likely  [Static Kitten, Helix Kitten]
# 303              100.0%  30-Day: Low confidence  [Static Kitten, Helix Kitten]
#
# [124 rows x 13 columns]

# %%
from collections import Counter

# Count frequency of each related threat actor in filtered_df

# Flatten the list of related threat actors
all_actors = [actor for actors in filtered_df['related_threat_actors'] for actor in actors]
actor_counts = Counter(all_actors)

# Convert to DataFrame for display
actor_freq_df = pd.DataFrame(actor_counts.items(), columns=['Threat Actor', 'Frequency']).sort_values('Frequency', ascending=False)

# Merge in 7d, 14d, 30d probabilities for each threat actor
# For each threat actor, compute the mean probability across all related indicators

# First, create a mapping from indicator to 7d/14d/30d probability
indicator_prob = filtered_df[['Indicator']].copy()
indicator_prob['7d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 7-Day'].values
indicator_prob['14d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 14-Day'].values
indicator_prob['30d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 30-Day'].values

# Explode related_threat_actors to associate each indicator with each actor
exploded = filtered_df[['Indicator', 'related_threat_actors']].explode('related_threat_actors')
exploded = exploded.merge(indicator_prob, left_on='Indicator', right_on='Indicator', how='left')

# Group by threat actor and aggregate mean probability (as string, so convert to float first)
def pct_to_float(s):
    return s.str.rstrip('%').astype(float)

actor_probs = (
    exploded.groupby('related_threat_actors')
    .agg(
        indicators=('Indicator', 'nunique'),
        mean_7d_prob=('7d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%"),
        mean_14d_prob=('14d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%"),
        mean_30d_prob=('30d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%")
    )
    .reset_index()
    .rename(columns={
        'related_threat_actors': 'Threat Actor',
        'mean_7d_prob': 'Mean 7-Day Probability (%)',
        'mean_14d_prob': 'Mean 14-Day Probability (%)',
        'mean_30d_prob': 'Mean 30-Day Probability (%)'
    })
)

# Add most common confidence for 7, 14, and 30 days for each threat actor
exploded_conf = filtered_df[['Indicator', 'related_threat_actors', 'Confidence: 7-Day', 'Confidence: 14-Day', 'Confidence: 30-Day']].explode('related_threat_actors')

def most_common(series):
    return series.mode().iloc[0] if not series.mode().empty else None

# Define ranking for confidence tags (higher is better)
confidence_rank = {
    'Highly likely': 3,
    'Possibly active': 2,
    'Low confidence': 1
}

def extract_ranked_confidence(series, window_label):
    # Extract the confidence string after the colon (e.g., "7-Day: Highly likely" -> "Highly likely")
    confs = series.dropna().astype(str).str.extract(rf'{window_label}:\s*(.*)')[0]
    if confs.empty:
        return None
    # Count occurrences
    counts = confs.value_counts()
    max_count = counts.max()
    # Get all tied values
    tied = counts[counts == max_count].index.tolist()
    # Pick the highest ranked
    ranked = sorted(tied, key=lambda x: -confidence_rank.get(x, 0))
    return f"{window_label}: {ranked[0]}" if ranked else None

"""actor_conf = (
    exploded_conf.groupby('related_threat_actors')
    .agg(
        confidence_7d=('Confidence: 7-Day', lambda x: extract_ranked_confidence(x, '7-Day')),
        confidence_14d=('Confidence: 14-Day', lambda x: extract_ranked_confidence(x, '14-Day')),
        confidence_30d=('Confidence: 30-Day', lambda x: extract_ranked_confidence(x, '30-Day'))
    )
    .reset_index()
    .rename(columns={
        'related_threat_actors': 'Threat Actor',
        'confidence_7d': 'Most Common 7-Day Confidence',
        'confidence_14d': 'Most Common 14-Day Confidence',
        'confidence_30d': 'Most Common 30-Day Confidence'
    })
)"""

# Merge with actor_freq_df
#actor_freq_df = actor_freq_df.merge(actor_conf, on='Threat Actor', how='left')
actor_freq_df = actor_freq_df.merge(actor_probs, on='Threat Actor', how='left')
actor_freq_df.drop(columns=['indicators'], inplace=True)
display(actor_freq_df)
# Out:
#              Threat Actor  Frequency Mean 7-Day Probability (%)  \
# 0                 UNC5537         50                     36.86%
# 1               Cozy Bear         21                     51.12%
# 2              Fancy Bear         20                     54.51%
# 3        Scattered Spider         14                     61.30%
# 4           Static Kitten          7                     68.44%
# 5       Seashell Blizzard          6                     36.39%
# 6                 UNC5221          6                     65.72%
# 7            Helix Kitten          3                     74.50%
# 8         Mustard Tempest          3                      7.30%
# 9          Primitive Bear          3                      4.58%
# 10                UNC5837          3                      2.86%
# 11                UNC5174          3                     70.66%
# 12                UNC5807          2                     13.28%
# 13                UNC4841          2                     24.75%
# 14          Carbon Spider          2                      7.41%
# 15        Revolver Rabbit          2                      0.39%
# 16           Flax Typhoon          2                     13.81%
# 17  Play Ransomware Group          1                      6.41%
# 18       Morphing Meerkat          1                      0.12%
# 19                UNC3313          1                     90.26%
# 20           Lace Tempest          1                     13.24%
# 21          Venomous Bear          1                     13.24%
# 22          Mustang Panda          1                      7.10%
# 23                UNC4936          1                     82.19%
# 24           Wicked Panda          1                      7.10%
# 25        Charming Kitten          1                      6.41%
# 26                UNC4487          1                     35.08%
# 27             Storm-2077          1                      0.00%
# 28                TAG-100          1                      0.00%
# 29                UNC1714          1                      0.23%
# 30       Kryptonite Panda          1                      0.23%
# 31                UNC5439          1                      0.14%
# 32          Circuit Panda          1                     83.85%
# 33         Dynamite Panda          1                     33.42%
# 34                  TA578          1                     33.42%
#
#    Mean 14-Day Probability (%) Mean 30-Day Probability (%)
# 0                       53.42%                      66.79%
# 1                       63.93%                      72.04%
# 2                       67.59%                      75.85%
# 3                       76.08%                      87.07%
# 4                       84.16%                      94.59%
# 5                       54.63%                      66.03%
# 6                       75.76%                      79.82%
# 7                       96.68%                     100.00%
# 8                       18.59%                      41.18%
# 9                        9.07%                      37.54%
# 10                       7.03%                      17.50%
# 11                      85.34%                      91.32%
# 12                      30.66%                      64.75%
# 13                      58.22%                      73.98%
# 14                      18.03%                      39.16%
# 15                       1.88%                      16.86%
# 16                      48.89%                      73.98%
# 17                      11.58%                      40.92%
# 18                       0.56%                       3.12%
# 19                      98.04%                     100.00%
# 20                      28.09%                      73.17%
# 21                      28.09%                      73.17%
# 22                      14.45%                      47.36%
# 23                      97.85%                     100.00%
# 24                      14.45%                      47.36%
# 25                      11.58%                      40.92%
# 26                      60.70%                      84.75%
# 27                       0.00%                       0.01%
# 28                       0.00%                       0.01%
# 29                       1.01%                      10.61%
# 30                       1.01%                      10.61%
# 31                       0.67%                       4.96%
# 32                     100.00%                     100.00%
# 33                      98.17%                     100.00%
# 34                      98.17%                     100.00%
