# %%
import pandas as pd
THREAT_ACTORS = r'Z:\HTOC\Data_Analytics\Data\Observed_Tags\htoc_observed_indicator_tags.csv'
production_output = pd.read_csv(r'C:\Users\jaskew\Documents\project_repository\notebooks\observationEventForecasting\production_output.csv')

# %%
# Load threat actor tag data from the specified CSV file
threat_actor_tags = pd.read_csv(THREAT_ACTORS)
display(threat_actor_tags)
# Out:
#                    indicator          type  \
# 0     003@tagmode-search.com  EmailAddress
# 1                 0secure.ru          Host
# 2                 0secure.ru          Host
# 3            1-you.njalla.no          Host
# 4            1-you.njalla.no          Host
# ...                      ...           ...
# 9161             zerocap.com          Host
# 9162             zerocap.com          Host
# 9163     zimbra@infinigi.com  EmailAddress
# 9164     zimbra@infinigi.com  EmailAddress
# 9165     zimbra@infinigi.com  EmailAddress
#
#                                             tag  threat_category
# 0                                       Malspam        TECHNIQUE
# 1                                Reconnaissance        TECHNIQUE
# 2                                      Phishing  MITRE_TECHNIQUE
# 3                                       Malspam        TECHNIQUE
# 4                                 CVE-2017-0199    VULNERABILITY
# ...                                         ...              ...
# 9161                                 SocGholish          MALWARE
# 9162  Ransomware/Ransomware-as-a-Service (RaaS)     MALWARE TYPE
# 9163                                Health-ISAC           SOURCE
# 9164                                   Phishing  MITRE_TECHNIQUE
# 9165                                Agent Tesla          MALWARE
#
# [9166 rows x 4 columns]

# %%
# Extract a list of unique threat actor tags from threat_actor_tags
threat_actor_tag_list = threat_actor_tags[
    threat_actor_tags['threat_category'].str.contains('THREAT ACTOR', case=False, na=False)
]['tag'].unique().tolist()
threat_actor_tag_list
# Out:
# ['Wicked Panda',
#  'Refined Kitten',
#  'Rocket Kitten',
#  'Cozy Bear',
#  'UNC5537',
#  'ShadowSyndicate',
#  'thedarkoverlord',
#  'UNC4841',
#  'UNC5807',
#  'Fancy Bear',
#  'Primitive Bear',
#  'Volt Typhoon',
#  'Seashell Blizzard',
#  'Star Blizzard',
#  'Scattered Spider',
#  'Morphing Meerkat',
#  'UNC3973',
#  'Mustang Panda',
#  'Indrik Spider',
#  'UNC5986',
#  'Pay-Per-Install Service',
#  'Mustard Tempest',
#  'Initial Access Broker',
#  'Cold River',
#  'Static Kitten',
#  'UNC5439',
#  'UNC5221',
#  'Charming Kitten',
#  'Play Ransomware Group',
#  'storm-0558',
#  'UNC5266',
#  'Lace Tempest',
#  'ALPHV',
#  'UNC4936',
#  'Flax Typhoon',
#  'Storm-1849',
#  'Venomous Bear',
#  'Unc5175',
#  'Unc5435',
#  'UNC5435',
#  'UNC5175',
#  'Asylum Ambuscade',
#  'Velvet Chollima',
#  'Machete',
#  '8220 Gang',
#  'UNC3313',
#  'UNC4487',
#  'UNC1714',
#  'Kryptonite Panda',
#  'Prophet Spider',
#  'storm-0494',
#  'Affiliates',
#  'UNC5837',
#  'Carbon Spider',
#  'Strawberry Tempest',
#  'noname(057)16',
#  'Storm-0866',
#  'UAT-4820',
#  'LilacSquid',
#  'LABRAT',
#  'TA582',
#  'Rhysida',
#  'Storm-2077',
#  'TAG-100',
#  'UNC4509',
#  'Deep Panda',
#  'UNC4536',
#  'Apothecary Spider',
#  'Storm-1113',
#  'UNC5174',
#  'Helix Kitten',
#  'Unfurling Hemlock',
#  'UNC4698',
#  'UNC3594',
#  'Crystalray',
#  'Ghostwriter',
#  'UNC1151',
#  'TA577',
#  'Circuit Panda',
#  'Anchor Panda',
#  'UNC3953',
#  'Boriselchin',
#  'Unc4681',
#  'UNC4899',
#  'TA578',
#  'Dynamite Panda',
#  'Hippo Team',
#  'Revolver Rabbit',
#  'Stardust Chollima',
#  'UNC5148',
#  'XeGroup']

# %%
matched_indicators = production_output['Indicator'].isin(threat_actor_tags['indicator'])
production_output_with_tags = production_output[matched_indicators]
# Merge in tags and threat categories from threat_actor_tags
production_output_with_tags = production_output_with_tags.merge(
    threat_actor_tags[['indicator', 'tag', 'threat_category']],
    left_on='Indicator',
    right_on='indicator',
    how='left'
)

display(production_output_with_tags)
# Out:
#              Indicator  Observed Today  Frequency (7d)  Frequency (30d)  \
# 0      1-you.njalla.no               0             1.0              1.0
# 1      1-you.njalla.no               0             1.0              1.0
# 2      1-you.njalla.no               0             1.0              1.0
# 3      1-you.njalla.no               0             1.0              1.0
# 4      1-you.njalla.no               0             1.0              1.0
# ...                ...             ...             ...              ...
# 1819  www.filemail.com               0             0.0              1.0
# 1820  www.filemail.com               0             0.0              1.0
# 1821  www.filemail.com               0             0.0              1.0
# 1822  www.filemail.com               0             0.0              1.0
# 1823  www.filemail.com               0             0.0              1.0
#
#      Probability: Today      Confidence: Today Probability: 7-Day  \
# 0                 3.07%  Today: Low confidence             56.58%
# 1                 3.07%  Today: Low confidence             56.58%
# 2                 3.07%  Today: Low confidence             56.58%
# 3                 3.07%  Today: Low confidence             56.58%
# 4                 3.07%  Today: Low confidence             56.58%
# ...                 ...                    ...                ...
# 1819              0.34%  Today: Low confidence             14.73%
# 1820              0.34%  Today: Low confidence             14.73%
# 1821              0.34%  Today: Low confidence             14.73%
# 1822              0.34%  Today: Low confidence             14.73%
# 1823              0.34%  Today: Low confidence             14.73%
#
#            Confidence: 7-Day Probability: 14-Day       Confidence: 14-Day  \
# 0     7-Day: Possibly active              65.42%  14-Day: Possibly active
# 1     7-Day: Possibly active              65.42%  14-Day: Possibly active
# 2     7-Day: Possibly active              65.42%  14-Day: Possibly active
# 3     7-Day: Possibly active              65.42%  14-Day: Possibly active
# 4     7-Day: Possibly active              65.42%  14-Day: Possibly active
# ...                      ...                 ...                      ...
# 1819   7-Day: Low confidence              75.29%   14-Day: Low confidence
# 1820   7-Day: Low confidence              75.29%   14-Day: Low confidence
# 1821   7-Day: Low confidence              75.29%   14-Day: Low confidence
# 1822   7-Day: Low confidence              75.29%   14-Day: Low confidence
# 1823   7-Day: Low confidence              75.29%   14-Day: Low confidence
#
#      Probability: 30-Day       Confidence: 30-Day         indicator  \
# 0                 74.36%  30-Day: Possibly active   1-you.njalla.no
# 1                 74.36%  30-Day: Possibly active   1-you.njalla.no
# 2                 74.36%  30-Day: Possibly active   1-you.njalla.no
# 3                 74.36%  30-Day: Possibly active   1-you.njalla.no
# 4                 74.36%  30-Day: Possibly active   1-you.njalla.no
# ...                  ...                      ...               ...
# 878     45.134.212.80               0             0.0              2.0
# 879      45.134.79.98               0             0.0              1.0
# 915     46.19.136.227               0             0.0              2.0
# 1384    79.127.217.35               0             0.0              1.0
# 1481      93.115.0.49               1             6.0              6.0
#
#      Probability: Today       Confidence: Today Probability: 7-Day  \
# 10                0.02%   Today: Low confidence              0.11%
# 35                0.01%   Today: Low confidence              0.36%
# 76               11.07%  Today: Possibly active             90.23%
# 79                0.52%   Today: Low confidence             31.99%
# 80                 0.0%   Today: Low confidence              0.01%
# 102               2.57%   Today: Low confidence             85.41%
# 124              88.42%    Today: Highly likely             100.0%
# 132               0.38%   Today: Low confidence             10.42%
# 133                0.0%   Today: Low confidence              0.01%
# 135               4.65%   Today: Low confidence             93.05%
# 143               0.03%   Today: Low confidence             12.18%
# 145               2.57%   Today: Low confidence             77.53%
# 153               0.58%   Today: Low confidence             12.87%
# 155                2.1%   Today: Low confidence             77.43%
# 163               0.05%   Today: Low confidence              6.53%
# 165                2.5%   Today: Low confidence             77.16%
# 177               0.02%   Today: Low confidence              0.09%
# 178               1.73%   Today: Low confidence             89.04%
# 188               0.01%   Today: Low confidence              0.02%
# 189               0.01%   Today: Low confidence              0.02%
# 190               0.01%   Today: Low confidence              0.01%
# 205              36.77%  Today: Possibly active             100.0%
# 214              33.53%  Today: Possibly active             99.33%
# 333               8.54%  Today: Possibly active             100.0%
# 336              45.15%  Today: Possibly active             100.0%
# 418               4.02%   Today: Low confidence             57.88%
# 450               0.58%   Today: Low confidence             40.83%
# 458               0.29%   Today: Low confidence              9.24%
# 603               0.02%   Today: Low confidence              0.09%
# 606              71.95%    Today: Highly likely             100.0%
# 633               2.07%   Today: Low confidence             79.34%
# 679               0.38%   Today: Low confidence             10.42%
# 687                4.6%   Today: Low confidence             58.41%
# 688               0.29%   Today: Low confidence              9.24%
# 695               0.01%   Today: Low confidence              0.02%
# 704               11.5%  Today: Possibly active             83.64%
# 713                0.0%   Today: Low confidence              0.01%
# 722               3.51%   Today: Low confidence             57.28%
# 731               0.02%   Today: Low confidence              0.09%
# 762              60.22%    Today: Highly likely             100.0%
# 770              17.75%  Today: Possibly active             99.54%
# 771               0.01%   Today: Low confidence              0.25%
# 772               0.01%   Today: Low confidence              0.02%
# 816               0.26%   Today: Low confidence             40.13%
# 866               0.02%   Today: Low confidence              0.49%
# 870              40.12%  Today: Possibly active             100.0%
# 872                4.6%   Today: Low confidence             58.41%
# 873               2.03%   Today: Low confidence             100.0%
# 874               2.39%   Today: Low confidence             100.0%
# 877               0.08%   Today: Low confidence             13.56%
# 878               0.36%   Today: Low confidence             21.19%
# 879               0.04%   Today: Low confidence               6.9%
# 915               0.21%   Today: Low confidence             18.22%
# 1384              0.11%   Today: Low confidence              8.15%
# 1481             91.59%    Today: Highly likely             100.0%
#
#            Confidence: 7-Day Probability: 14-Day       Confidence: 14-Day  \
# 10     7-Day: Low confidence               0.16%   14-Day: Low confidence
# 35     7-Day: Low confidence               1.92%   14-Day: Low confidence
# 76      7-Day: Highly likely              98.08%    14-Day: Highly likely
# 79     7-Day: Low confidence              85.49%   14-Day: Low confidence
# 870               100.0%    30-Day: Highly likely      37.19.210.2  UNC5537
# 872               74.67%  30-Day: Possibly active    38.240.225.37  UNC5537
# 873               100.0%  30-Day: Possibly active   43.225.189.132  UNC5537
# 874               100.0%  30-Day: Possibly active   43.225.189.163  UNC5537
# 877               99.25%   30-Day: Low confidence   45.134.140.131  UNC5537
# 878               100.0%   30-Day: Low confidence    45.134.212.80  UNC5537
# 879                76.9%   30-Day: Low confidence     45.134.79.98  UNC5537
# 915               100.0%   30-Day: Low confidence    46.19.136.227  UNC5537
# 1384               91.8%   30-Day: Low confidence    79.127.217.35  UNC5537
# 1481              100.0%    30-Day: Highly likely      93.115.0.49  UNC5537
#
#      threat_category
# 10      THREAT ACTOR
# 35      THREAT ACTOR
# 76      THREAT ACTOR
# 79      THREAT ACTOR
# 80      THREAT ACTOR
# 102     THREAT ACTOR
# 124     THREAT ACTOR
# 132     THREAT ACTOR
# 133     THREAT ACTOR
# 135     THREAT ACTOR
# 143     THREAT ACTOR
# 145     THREAT ACTOR
# 153     THREAT ACTOR
# 155     THREAT ACTOR
# 163     THREAT ACTOR
# 165     THREAT ACTOR
# 177     THREAT ACTOR
# 178     THREAT ACTOR
# 188     THREAT ACTOR
# 189     THREAT ACTOR
# 190     THREAT ACTOR
# 205     THREAT ACTOR
# 214     THREAT ACTOR
# 333     THREAT ACTOR
# 336     THREAT ACTOR
# 418     THREAT ACTOR
# 450     THREAT ACTOR
# 458     THREAT ACTOR
# 603     THREAT ACTOR
# 606     THREAT ACTOR
# 633     THREAT ACTOR
# 679     THREAT ACTOR
# 687     THREAT ACTOR
# 688     THREAT ACTOR
# 695     THREAT ACTOR
# 704     THREAT ACTOR
# 713     THREAT ACTOR
# 722     THREAT ACTOR
# 731     THREAT ACTOR
# 762     THREAT ACTOR
# 770     THREAT ACTOR
# 771     THREAT ACTOR
# 772     THREAT ACTOR
# 816     THREAT ACTOR
# 866     THREAT ACTOR
# 870     THREAT ACTOR
# 872     THREAT ACTOR
# 873     THREAT ACTOR
# 874     THREAT ACTOR
# 877     THREAT ACTOR
# 878     THREAT ACTOR
# 879     THREAT ACTOR
# 915     THREAT ACTOR
# 1384    THREAT ACTOR
# 1481    THREAT ACTOR

# %%
# Condense tags for each indicator into a single row with lists of tags and threat categories
condensed = (
    production_output_with_tags
    .groupby('Indicator')
    .agg({
        'Observed Today': 'first',
        'Frequency (7d)': 'first',
        'Frequency (30d)': 'first',
        'Probability: Today': 'first',
        'Confidence: Today': 'first',
        'Probability: 7-Day': 'first',
        'Confidence: 7-Day': 'first',
        'Probability: 14-Day': 'first',
        'Confidence: 14-Day': 'first',
        'Probability: 30-Day': 'first',
        'Confidence: 30-Day': 'first',
        'tag': lambda x: list(x.unique()),
        'threat_category': lambda x: list(x.dropna().unique())
    })
    .reset_index()
)

display(condensed)
# Out:
#                                Indicator  Observed Today  Frequency (7d)  \
# 0                        1-you.njalla.no               0             1.0
# 1                         103.108.231.67               0             0.0
# 2                        103.149.249.226               0             0.0
# 3                          103.77.192.88               0             0.0
# 4                        104.128.161.233               0             3.0
# ..                                   ...             ...             ...
# 313                            vtext.com               1             7.0
# 314                        ws.onehub.com               0             3.0
# 315                           www.3u.com               0             0.0
# 316  www.deepseek.com.cdn.cloudflare.net               1             7.0
# 317                     www.filemail.com               0             0.0
#
#      Frequency (30d) Probability: Today       Confidence: Today  \
# 0                1.0              3.07%   Today: Low confidence
# 1                0.0              0.02%   Today: Low confidence
# 2                0.0               0.0%   Today: Low confidence
# 3                1.0              0.08%   Today: Low confidence
# 4               26.0               8.7%  Today: Possibly active
# ..               ...                ...                     ...
# 313             30.0             81.53%    Today: Highly likely
# 314              6.0             17.45%  Today: Possibly active
# 315              0.0               0.0%   Today: Low confidence
# 316             24.0             85.12%    Today: Highly likely
# 317              1.0              0.34%   Today: Low confidence
#
#     Probability: 7-Day       Confidence: 7-Day Probability: 14-Day  \
# 0               56.58%  7-Day: Possibly active              65.42%
# 1                0.11%   7-Day: Low confidence               0.16%
# 2                0.03%   7-Day: Low confidence               0.13%
# 3                6.85%   7-Day: Low confidence              13.37%
# 4               100.0%    7-Day: Highly likely              100.0%
# ..                 ...                     ...                 ...
# 313             100.0%    7-Day: Highly likely              100.0%
# 314             100.0%    7-Day: Highly likely              100.0%
# 315               0.0%   7-Day: Low confidence                0.0%
# 316             100.0%    7-Day: Highly likely              100.0%
# 317             14.73%   7-Day: Low confidence              75.29%
#
#           Confidence: 14-Day Probability: 30-Day       Confidence: 30-Day  \
# 0    14-Day: Possibly active              74.36%  30-Day: Possibly active
# 1     14-Day: Low confidence               8.89%   30-Day: Low confidence
# 2     14-Day: Low confidence               1.14%   30-Day: Low confidence
# 3     14-Day: Low confidence              67.96%   30-Day: Low confidence
# 4      14-Day: Highly likely              100.0%    30-Day: Highly likely
# ..                       ...                 ...                      ...
# 313    14-Day: Highly likely              100.0%    30-Day: Highly likely
# 314    14-Day: Highly likely              100.0%    30-Day: Highly likely
# 315   14-Day: Low confidence               0.09%   30-Day: Low confidence
# 316    14-Day: Highly likely              100.0%    30-Day: Highly likely
# 317   14-Day: Low confidence              98.55%   30-Day: Low confidence
#
#                                                    tag  \
# 0    [Malspam, CVE-2017-0199, Cobalt Strike, Acquir...
# 1                                            [UNC5537]
# 2                            [CVE-2024-4040, CrushFTP]
# 3    [ghostloot, UNC5807, Reconnaissance, STOWAWAY,...
# 4    [Cozy Bear, Fancy Bear, GRU, GRIZZLY STEPPE, G...
# ..                                                 ...
# 313                     [Phishing, Gootloader Malware]
# 314  [SyncroMSP, Unified Endpoint Management, Stati...
# 315                                       [multiverze]
# 316                                         [DeepSeek]
# 317  [SyncroMSP, Unified Endpoint Management, Stati...
#
#                                        threat_category
# 0    [TECHNIQUE, VULNERABILITY, MALWARE, MITRE_TECH...
# 1                                       [THREAT ACTOR]
# 2                                      [VULNERABILITY]
# 3    [MALWARE, THREAT ACTOR, TECHNIQUE, MITRE_TECHN...
# 4    [THREAT ACTOR, SPONSOR ORGANIZATION, CAMPAIGN,...
# ..                                                 ...
# 313                         [MITRE_TECHNIQUE, MALWARE]
# 314  [THREAT ACTOR, MALWARE, TECHNIQUE, SPONSOR ORG...
# 315                                                 []
# 316                                    [VULNERABILITY]
# 317  [THREAT ACTOR, TECHNIQUE, SPONSOR ORGANIZATION...
#
# [318 rows x 14 columns]

# %%
filtered_df = condensed[condensed['tag'].apply(lambda tags: any(tag in threat_actor_tag_list for tag in tags))].copy()

# Create column of related threat actor
filtered_df.loc[:, 'related_threat_actors'] = filtered_df['tag'].apply(
    lambda tags: [tag for tag in tags if tag in threat_actor_tag_list]
)
filtered_df = filtered_df.drop(columns=['tag', 'threat_category'])
display(filtered_df)
# Out:
#                Indicator  Observed Today  Frequency (7d)  Frequency (30d)  \
# 0        1-you.njalla.no               0             1.0              1.0
# 1         103.108.231.67               0             0.0              0.0
# 3          103.77.192.88               0             0.0              1.0
# 4        104.128.161.233               0             3.0             26.0
# 5         104.129.24.124               0             0.0              0.0
# ..                   ...             ...             ...              ...
# 304    prosinthecity.com               0             0.0              0.0
# 305       r3.o.lencr.org               0             0.0              1.0
# 308  summerwaterhall.com               0             0.0              2.0
# 314        ws.onehub.com               0             3.0              6.0
# 317     www.filemail.com               0             0.0              1.0
#
#     Probability: Today       Confidence: Today Probability: 7-Day  \
# 0                3.07%   Today: Low confidence             56.58%
# 1                0.02%   Today: Low confidence              0.11%
# 3                0.08%   Today: Low confidence              6.85%
# 4                 8.7%  Today: Possibly active             100.0%
# 5                0.01%   Today: Low confidence              0.36%
# ..                 ...                     ...                ...
# 304              0.03%   Today: Low confidence              0.13%
# 305              0.14%   Today: Low confidence              8.68%
# 308              0.14%   Today: Low confidence             15.71%
# 314             17.45%  Today: Possibly active             100.0%
# 317              0.34%   Today: Low confidence             14.73%
#
#           Confidence: 7-Day Probability: 14-Day       Confidence: 14-Day  \
# 0    7-Day: Possibly active              65.42%  14-Day: Possibly active
# 1     7-Day: Low confidence               0.16%   14-Day: Low confidence
# 3     7-Day: Low confidence              13.37%   14-Day: Low confidence
# 4      7-Day: Highly likely              100.0%    14-Day: Highly likely
# 5     7-Day: Low confidence               1.92%   14-Day: Low confidence
# ..                      ...                 ...                      ...
# 304   7-Day: Low confidence               0.22%   14-Day: Low confidence
# 305   7-Day: Low confidence              25.13%   14-Day: Low confidence
# 308   7-Day: Low confidence              40.75%   14-Day: Low confidence
# 314    7-Day: Highly likely              100.0%    14-Day: Highly likely
# 317   7-Day: Low confidence              75.29%   14-Day: Low confidence
#
#     Probability: 30-Day       Confidence: 30-Day  \
# 0                74.36%  30-Day: Possibly active
# 1                 8.89%   30-Day: Low confidence
# 3                67.96%   30-Day: Low confidence
# 4                100.0%    30-Day: Highly likely
# 5                 11.4%   30-Day: Low confidence
# ..                  ...                      ...
# 304              10.37%   30-Day: Low confidence
# 305              94.73%   30-Day: Low confidence
# 308              100.0%   30-Day: Low confidence
# 314              100.0%    30-Day: Highly likely
# 317              98.55%   30-Day: Low confidence
#
#              related_threat_actors
# 0                   [Wicked Panda]
# 1                        [UNC5537]
# 3               [UNC5807, UNC4841]
# 4          [Cozy Bear, Fancy Bear]
# 5                        [UNC5537]
# ..                             ...
# 304              [Mustard Tempest]
# 305              [Mustard Tempest]
# 308                    [Cozy Bear]
# 314  [Static Kitten, Helix Kitten]
# 317  [Static Kitten, Helix Kitten]
#
# [134 rows x 13 columns]

# %%
from collections import Counter

# Count frequency of each related threat actor in filtered_df

# Flatten the list of related threat actors
all_actors = [actor for actors in filtered_df['related_threat_actors'] for actor in actors]
actor_counts = Counter(all_actors)

# Convert to DataFrame for display
actor_freq_df = pd.DataFrame(actor_counts.items(), columns=['Threat Actor', 'Frequency']).sort_values('Frequency', ascending=False)

# Merge in 7d, 14d, 30d probabilities for each threat actor
# For each threat actor, compute the mean probability across all related indicators

# First, create a mapping from indicator to 7d/14d/30d probability
indicator_prob = filtered_df[['Indicator']].copy()
indicator_prob['7d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 7-Day'].values
indicator_prob['14d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 14-Day'].values
indicator_prob['30d_prob'] = production_output.set_index('Indicator').loc[indicator_prob['Indicator'], 'Probability: 30-Day'].values

# Explode related_threat_actors to associate each indicator with each actor
exploded = filtered_df[['Indicator', 'related_threat_actors']].explode('related_threat_actors')
exploded = exploded.merge(indicator_prob, left_on='Indicator', right_on='Indicator', how='left')

# Group by threat actor and aggregate mean probability (as string, so convert to float first)
def pct_to_float(s):
    return s.str.rstrip('%').astype(float)

actor_probs = (
    exploded.groupby('related_threat_actors')
    .agg(
        indicators=('Indicator', 'nunique'),
        mean_7d_prob=('7d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%"),
        mean_14d_prob=('14d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%"),
        mean_30d_prob=('30d_prob', lambda x: f"{pct_to_float(x).mean():.2f}%")
    )
    .reset_index()
    .rename(columns={
        'related_threat_actors': 'Threat Actor',
        'mean_7d_prob': 'Mean 7-Day Probability (%)',
        'mean_14d_prob': 'Mean 14-Day Probability (%)',
        'mean_30d_prob': 'Mean 30-Day Probability (%)'
    })
)

# Add most common confidence for 7, 14, and 30 days for each threat actor
exploded_conf = filtered_df[['Indicator', 'related_threat_actors', 'Confidence: 7-Day', 'Confidence: 14-Day', 'Confidence: 30-Day']].explode('related_threat_actors')

def most_common(series):
    return series.mode().iloc[0] if not series.mode().empty else None

# Define ranking for confidence tags (higher is better)
confidence_rank = {
    'Highly likely': 3,
    'Possibly active': 2,
    'Low confidence': 1
}

def extract_ranked_confidence(series, window_label):
    # Extract the confidence string after the colon (e.g., "7-Day: Highly likely" -> "Highly likely")
    confs = series.dropna().astype(str).str.extract(rf'{window_label}:\s*(.*)')[0]
    if confs.empty:
        return None
    # Count occurrences
    counts = confs.value_counts()
    max_count = counts.max()
    # Get all tied values
    tied = counts[counts == max_count].index.tolist()
    # Pick the highest ranked
    ranked = sorted(tied, key=lambda x: -confidence_rank.get(x, 0))
    return f"{window_label}: {ranked[0]}" if ranked else None

"""actor_conf = (
    exploded_conf.groupby('related_threat_actors')
    .agg(
        confidence_7d=('Confidence: 7-Day', lambda x: extract_ranked_confidence(x, '7-Day')),
        confidence_14d=('Confidence: 14-Day', lambda x: extract_ranked_confidence(x, '14-Day')),
        confidence_30d=('Confidence: 30-Day', lambda x: extract_ranked_confidence(x, '30-Day'))
    )
    .reset_index()
    .rename(columns={
        'related_threat_actors': 'Threat Actor',
        'confidence_7d': 'Most Common 7-Day Confidence',
        'confidence_14d': 'Most Common 14-Day Confidence',
        'confidence_30d': 'Most Common 30-Day Confidence'
    })
)"""

# Merge with actor_freq_df
#actor_freq_df = actor_freq_df.merge(actor_conf, on='Threat Actor', how='left')
actor_freq_df = actor_freq_df.merge(actor_probs, on='Threat Actor', how='left')
actor_freq_df.drop(columns=['indicators'], inplace=True)
display(actor_freq_df)
# Out:
#              Threat Actor  Frequency Mean 7-Day Probability (%)  \
# 0                 UNC5537         55                     44.31%
# 1               Cozy Bear         21                     46.76%
# 2              Fancy Bear         20                     49.96%
# 3        Scattered Spider         15                     64.16%
# 4           Static Kitten          7                     72.58%
# 5       Seashell Blizzard          6                     44.68%
# 6                 UNC5221          6                     62.73%
# 7            Wicked Panda          4                     44.10%
# 8                 UNC5174          3                     69.59%
# 9          Primitive Bear          3                      0.21%
# 10                UNC5837          3                      2.44%
# 11          Carbon Spider          3                     23.53%
# 12        Mustard Tempest          3                      2.94%
# 13           Helix Kitten          3                     69.66%
# 14                UNC5807          2                     12.27%
# 15        Revolver Rabbit          2                      0.20%
# 16           Flax Typhoon          2                     44.32%
# 17                UNC4841          2                     25.69%
# 18        Charming Kitten          1                      0.09%
# 19                UNC3313          1                    100.00%
# 20           Lace Tempest          1                     12.35%
# 21          Venomous Bear          1                     12.35%
# 22          Mustang Panda          1                      6.66%
# 23  Play Ransomware Group          1                      0.09%
# 24                UNC4936          1                     67.54%
# 25       Morphing Meerkat          1                      0.08%
# 26                UNC4487          1                     32.99%
# 27                TAG-100          1                      0.00%
# 28             Storm-2077          1                      0.00%
# 29                UNC1714          1                      0.09%
# 30       Kryptonite Panda          1                      0.09%
# 31                UNC5439          1                      0.06%
# 32          Circuit Panda          1                     89.41%
# 33         Dynamite Panda          1                     20.78%
# 34                  TA578          1                     20.78%
#
#    Mean 14-Day Probability (%) Mean 30-Day Probability (%)
# 0                       55.91%                      68.57%
# 1                       61.63%                      71.98%
# 2                       65.37%                      75.57%
# 3                       74.13%                      85.12%
# 4                       84.38%                      97.08%
# 5                       52.32%                      70.23%
# 6                       69.86%                      79.25%
# 7                       52.17%                      72.14%
# 8                       74.87%                      90.95%
# 9                        0.69%                      13.12%
# 10                       5.32%                      23.83%
# 11                      31.45%                      58.16%
# 12                       8.47%                      35.23%
# 13                      91.76%                      99.52%
# 14                      24.59%                      83.98%
# 15                       0.95%                      10.50%
# 16                      70.89%                     100.00%
# 17                      54.34%                      83.98%
# 18                       0.12%                       7.54%
# 19                     100.00%                     100.00%
# 20                      23.79%                      92.18%
# 21                      23.79%                      92.18%
# 22                      12.44%                      65.47%
# 23                       0.12%                       7.54%
# 24                      94.22%                     100.00%
# 25                       0.46%                       2.96%
# 26                      53.96%                     100.00%
# 27                       0.00%                       0.00%
# 28                       0.00%                       0.00%
# 29                       0.38%                       5.16%
# 30                       0.38%                       5.16%
# 31                       0.29%                       2.63%
# 32                     100.00%                     100.00%
# 33                      84.17%                     100.00%
# 34                      84.17%                     100.00%
