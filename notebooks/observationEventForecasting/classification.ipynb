# %%
import pandas as pd 
import numpy as np

# %%
#import data from /Users/jaytlinaskew/GitRepository/TimeSeries-Analysis/data/processed/ProcessedObservedData.csv
data = pd.read_csv('/Users/jaytlinaskew/GitRepository/TimeSeries-Analysis/data/processed/ProcessedObservedData.csv', parse_dates=['obs_date'], index_col='obs_date')
#filter by opDiv CDC
data = data[data['OpDiv'] == 'CDC']
data.drop(columns=['curr_date'], inplace=True)
data.head(10)
# Out:
#                   indicator          API_UserName OpDiv  observations
# obs_date
# 2025-01-01    146.71.50.198  00818860012482918321   CDC             1
# 2025-01-01    149.36.49.225  00818860012482918321   CDC            28
# 2025-01-01  162.142.125.242  00818860012482918321   CDC             3
# 2025-01-01  162.142.125.247  00818860012482918321   CDC             2
# 2025-01-01  162.142.125.255  00818860012482918321   CDC             3
# 2025-01-01   185.230.63.171  00818860012482918321   CDC             6
# 2025-01-01     23.26.221.12  00818860012482918321   CDC            49
# 2025-01-01      23.26.221.2  00818860012482918321   CDC            51
# 2025-01-01      23.26.221.4  00818860012482918321   CDC            36
# 2025-01-01   34.160.111.145  00818860012482918321   CDC             4
