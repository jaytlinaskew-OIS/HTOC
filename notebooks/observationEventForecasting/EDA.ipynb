# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/jaytlinaskew/GitRepository/TimeSeries-Analysis/notebooks/observationEventForecasting/DataPreprocessing/FullIndicatorMatrix.csv')
data.head()
# Out:
#          API_UserName        date        indicator  observations  dayofweek  \
# 0  818860012482918321  2025-01-01    146.71.50.198             1          2
# 1  818860012482918321  2025-01-01    149.36.49.225            28          2
# 2  818860012482918321  2025-01-01  162.142.125.242             3          2
# 3  818860012482918321  2025-01-01  162.142.125.247             2          2
# 4  818860012482918321  2025-01-01  162.142.125.255             3          2
#
#    is_weekend  day  month  seen
# 0       False    1      1     1
# 1       False    1      1     1
# 2       False    1      1     1
# 3       False    1      1     1
# 4       False    1      1     1

# %%
correct = data[data['indicator'] == '104.21.48.1']
correct
# Out:
#              API_UserName        date    indicator  observations  dayofweek  \
# 115    818860012482918321  2025-01-01  104.21.48.1             0          2
# 321    818860012482918321  2025-01-02  104.21.48.1             0          3
# 527    818860012482918321  2025-01-03  104.21.48.1             0          4
# 733    818860012482918321  2025-01-04  104.21.48.1             0          5
# 939    818860012482918321  2025-01-05  104.21.48.1             0          6
# ...                   ...         ...          ...           ...        ...
# 23599  818860012482918321  2025-04-25  104.21.48.1          4491          4
# 23805  818860012482918321  2025-04-26  104.21.48.1           325          5
# 24011  818860012482918321  2025-04-27  104.21.48.1           415          6
# 24217  818860012482918321  2025-04-28  104.21.48.1          4003          0
# 24423  818860012482918321  2025-04-29  104.21.48.1          1058          1
#
#        is_weekend  day  month  seen
# ...

# %%
# Ensure 'date' column in 'correct' DataFrame is in datetime format
correct.loc[:, 'date'] = pd.to_datetime(correct['date'], errors='coerce')

# Plot time series for each unique indicator in 'correct'
indicators = correct['indicator'].unique()
rows = len(indicators)
cols = 1
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten() if rows > 1 else [axes]  # Handle single subplot case

for i, indicator in enumerate(indicators):
    ax = axes[i]
    indicator_data = correct[correct['indicator'] == indicator]
    ax.plot(indicator_data['date'], indicator_data['seen'], label=f'Correct: {indicator}', color='green')
    ax.set_title(f'Correct: {indicator}')
    ax.set_xlabel('Date')
    ax.set_ylabel('Seen (1 = Yes, 0 = No)')
    ax.legend(loc='upper right')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
wrong = data[data['indicator'] == '162.142.125.247']

# %%
# Ensure 'date' column in 'wrong' DataFrame is in datetime format
wrong.loc[:, 'date'] = pd.to_datetime(wrong['date'], errors='coerce')

# Plot time series for each unique indicator in 'correct'
indicators = wrong['indicator'].unique()
rows = len(indicators)
cols = 1
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten() if rows > 1 else [axes]  # Handle single subplot case

for i, indicator in enumerate(indicators):
    ax = axes[i]
    indicator_data = wrong[wrong['indicator'] == indicator]
    ax.plot(indicator_data['date'], indicator_data['seen'], label=f'Correct: {indicator}', color='green')
    ax.set_title(f'Correct: {indicator}')
    ax.set_xlabel('Date')
    ax.set_ylabel('Seen (1 = Yes, 0 = No)')
    ax.legend(loc='upper right')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
correct2 = data[data['indicator'] == '172.240.108.68']
correct2.head(90)
# Out:
#              API_UserName        date       indicator  observations  \
# 16     818860012482918321  2025-01-01  172.240.108.68             0
# 222    818860012482918321  2025-01-02  172.240.108.68            67
# 428    818860012482918321  2025-01-03  172.240.108.68             0
# 634    818860012482918321  2025-01-04  172.240.108.68             0
# 840    818860012482918321  2025-01-05  172.240.108.68             3
# ...                   ...         ...             ...           ...
# 17526  818860012482918321  2025-03-27  172.240.108.68           112
# 17732  818860012482918321  2025-03-28  172.240.108.68            57
# 17938  818860012482918321  2025-03-29  172.240.108.68             3
# 18144  818860012482918321  2025-03-30  172.240.108.68            11
# 18350  818860012482918321  2025-03-31  172.240.108.68           135
#
#        dayofweek  is_weekend  day  month  seen
# 16             2       False    1      1     0
# 222            3       False    2      1     1
# ...

# %%
correct2.loc[:, 'date'] = pd.to_datetime(wrong['date'], errors='coerce')

# Plot time series for each unique indicator in 'correct'
indicators = correct2['indicator'].unique()
rows = len(indicators)
cols = 1
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))
axes = axes.flatten() if rows > 1 else [axes]  # Handle single subplot case

for i, indicator in enumerate(indicators):
    ax = axes[i]
    indicator_data = correct2[correct2['indicator'] == indicator]
    ax.plot(indicator_data['date'], indicator_data['seen'], label=f'Correct: {indicator}', color='green')
    ax.set_title(f'Correct: {indicator}')
    ax.set_xlabel('Date')
    ax.set_ylabel('Seen (1 = Yes, 0 = No)')
    ax.legend(loc='upper right')
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1813, in Axis.convert_units(self, x)
#    1812 try:
# -> 1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/dates.py:1829, in _SwitchableDateConverter.convert(self, *args, **kwargs)
#    1828 def convert(self, *args, **kwargs):
# -> 1829     return self._get_converter().convert(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/dates.py:1757, in DateConverter.convert(value, unit, axis)
#    1751 """
#    1752 If *value* is not already a number or sequence of numbers, convert it
#    1753 with `date2num`.
#    1754
#    1755 The *unit* and *axis* arguments are not used.
#    1756 """
# -> 1757 return date2num(value)
#
# ...
