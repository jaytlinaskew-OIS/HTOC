# %%
import pandas as pd

# %%
data = [
    {'name': 'John', 'age': 30, 'city': 'New York'},
    {'name': 'Jane', 'age': 25, 'city': 'Los Angeles'},
    {'name': 'Mike', 'age': 32, 'city': 'Chicago'}
]

df = pd.DataFrame(data)
for col in df.columns:
    #capitalize column names
    df.rename(columns={col: col.capitalize()}, inplace=True)


display(df)
# Out:
#    Name  Age         City
# 0  John   30     New York
# 1  Jane   25  Los Angeles
# 2  Mike   32      Chicago

# %%
import timeit, tracemalloc, numpy as np

# ── 1. Inefficient: Python loop (object-by-object) ──
def inefficient_loop(n=1_000_000):
    total = 0
    for i in range(n):
        total += (i*i + 3*i) % 7     # every iteration creates 3-4 Python ints
    return total

# ── 2. Efficient: NumPy vectorised (bulk, in C) ──
def efficient_numpy(n=1_000_000):
    arr = np.arange(n, dtype=np.int64)           # 8 MB contiguous buffer
    res = (arr*arr + 3*arr) % 7                  # done by SIMD-optimised C code
    return res.sum()

# quick helper for timing + peak-RAM
def bench(fn):
    wall = timeit.timeit(lambda: fn(), number=3) / 3
    tracemalloc.start(); fn(); _, peak = tracemalloc.get_traced_memory(); tracemalloc.stop()
    return wall, peak/1_048_576             # MiB

# %%
# Call inefficient_loop function
result_inefficient = inefficient_loop()
print(f"Result of inefficient_loop: {result_inefficient}")
# Out:
# Result of inefficient_loop: 2999997

# %%
# Call efficient_numpy function
result_efficient = efficient_numpy()
print(f"Result of efficient_numpy: {result_efficient}")
# Out:
# Result of efficient_numpy: 2999997

# %%
# Call bench function for both inefficient_loop and efficient_numpy
time_inefficient, memory_inefficient = bench(inefficient_loop)
print(f"Inefficient Loop - Time: {time_inefficient:.6f}s, Peak Memory: {memory_inefficient:.2f} MiB")
time_efficient, memory_efficient = bench(efficient_numpy)
print(f"Efficient NumPy - Time: {time_efficient:.6f}s, Peak Memory: {memory_efficient:.2f} MiB")
# Out:
# Inefficient Loop - Time: 0.236206s, Peak Memory: 0.00 MiB
# Efficient NumPy - Time: 0.022503s, Peak Memory: 30.52 MiB
