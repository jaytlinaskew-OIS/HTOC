# %%
import pandas as pd

# Load the Excel file
file_path = r"Z:\HTOC\Data_Analytics\Data\Threat Assessment Scores\Threat_Assessment_Scores.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows
df
# Out:
#             Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 0     1-you.njalla.no    2026-02-03           Host                        34
# 1         1.234.83.26    2026-02-14        Address                        43
# 2      101.168.57.163    2026-02-14        Address                         2
# 3       101.71.130.99    2026-03-03        Address                       139
# 4      103.114.96.246    2026-02-26        Address                        41
# ...               ...           ...            ...                       ...
# 2256     5.79.110.170    2025-12-23        Address                         6
# 2257   146.70.246.116    2026-01-19        Address                         3
# 2258  198.199.103.243    2026-01-16        Address                         1
# 2259      rosesci.com    2026-01-08           Host                        17
# 2260    52.87.206.242    2026-01-08        Address                         1
#
#       ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 0                        5                        0.998137            0
# 1                        3                        0.997644            0
# 2                        3                        0.999890            0
# 3                        3                        0.992384            0
# 4                        1                        0.997753            1
# ...                    ...                             ...          ...
# 2256                     0                        0.999671            1
# 2257                     0                        0.999836            1
# 2258                     0                        0.999945            1
# 2259                     0                        0.999068            0
# 2260                     1                        0.999945            1
#
#       False Positives                                Partners  \
# 0                   0                                 NIH, VA
# 1                   0                 CMS, FDA, HRSA, IHS, OS
# 2                   0                        CMS, FDA, OS, VA
# 3                   0  CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS
# 4                   0                   CMS, DHA, NIH, OS, VA
# ...               ...                                     ...
# 2256                0                           CDC, CMS, HHS
# 2257                0                                      VA
# 2258                0                                      VA
# 2259                0                                     NIH
# 2260                0                                     IHS
#
#                                incidents/events    Threat Actor  CAL Score  \
# 0                                           NaN    Wicked Panda        180
# 1                                           NaN             NaN        180
# 2                                           NaN             NaN        180
# 3                                           NaN             NaN        540
# 4                                           NaN  Mr Hamza Group        180
# ...                                         ...             ...        ...
# 2256  Incident:6755399448003491;Incident:529312             NaN        170
# 2257                  Incident:6755399478001848             NaN        180
# 2258                  Incident:6755399478001848             NaN        180
# 2259                                        NaN             NaN        170
# 2260                                        NaN             NaN        170
#
#       ThreatConnect Score  HTOC Threat Score Severity  \
# 0                     416                312   medium
# 1                     469                199      low
# 2                     590                555     high
# 3                     526                467   medium
# 4                     229                142      low
# ...                   ...                ...      ...
# 2256                  363                 45      low
# 2257                  368                 41      low
# 2258                  368                 41      low
# 2259                  351                 30      low
# 2260                  224                 27      low
#
#                                             Explanation
# 0     [2026-03-05] Severity: medium. VT score not av...
# 1     [2026-03-05] Severity: low. VT score: 3. Top d...
# 2     [2026-03-05] Severity: high. VT score: 11. Top...
# 3     [2026-03-05] Severity: medium. VT score: 11. T...
# 4     [2026-03-05] Severity: low. VT score: 2. Top d...
# ...                                                 ...
# 2256  Severity: low. VT score: 0. Top drivers: Incid...
# 2257  Severity: low. VT score: 0. Top drivers: Incid...
# 2258  Severity: low. VT score: 0. Top drivers: Incid...
# 2259  Severity: low. Could not pull VT score to calc...
# 2260  Severity: low. VT score: 0. Top drivers: TC ra...
#
# [2261 rows x 16 columns]

# %%
import pandas as pd

# Ensure Last Observed is datetime
df['Last Observed'] = pd.to_datetime(df['Last Observed'])

# Get last 24 hours relative to latest observation
max_obs = df['Last Observed'].max()
cutoff = max_obs - pd.Timedelta(days=1)
last_24h_from_max = df[df['Last Observed'] >= cutoff]

last_24h_from_max
# Out:
#                                Indicator Last Observed Indicator Type  \
# 5                        103.120.116.162    2026-03-05        Address
# 7                          103.140.62.43    2026-03-04        Address
# 8                          103.143.10.79    2026-03-05        Address
# 10                        103.172.81.132    2026-03-05        Address
# 11                          103.203.59.0    2026-03-05        Address
# ...                                  ...           ...            ...
# 1401                     193.142.147.111    2026-03-05        Address
# 1402                          44.206.3.7    2026-03-04        Address
# 1403                        64.225.66.97    2026-03-05        Address
# 1404                       80.87.206.241    2026-03-05        Address
# 1405  grobinson@blueridgeinfosystems.com    2026-03-04   EmailAddress
#
#       Observation Yearly Count  ThreatConnect Rating  \
# 5                           37                     3
# 7                            6                     5
# 8                            6                     3
# 10                          42                     0
# 11                         271                     3
# ...                        ...                   ...
# 1401                         1                     3
# 1402                         1                     3
# 1403                         2                     2
# 1404                         1                     4
# 1405                         3                     3
#
#       Observation Penalty Multiplier  Botnet Flag  False Positives  \
# 5                           0.997973            0                0
# 7                           0.999671            0                0
# 8                           0.999671            0                0
# 10                          0.997699            0                0
# 11                          0.985151            0                0
# ...                              ...          ...              ...
# 1401                        0.999945            0                0
# 1402                        0.999945            0                0
# 1403                        0.999890            0                0
# 1404                        0.999945            0                0
# 1405                        0.999836            0                0
#
#                                     Partners  \
# 5      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 7                                    DHA, VA
# 8      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 10                    CMS, FDA, HHS, NIH, VA
# 11    CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS
# ...                                      ...
# 1401                                     HHS
# 1402                                     NIH
# 1403                           CMS, DHA, NIH
# 1404                                CMS, HHS
# 1405              CDC, CMS, FDA, HHS, OS, VA
#
#                                        incidents/events  \
# 5                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 10    Incident:5629499550000872;Incident:56294995470...
# 11                                                  NaN
# ...                                                 ...
# 1401                                                NaN
# 1402                                                NaN
# 1403                             Event:5629499536001088
# 1404                                                NaN
# 1405                                                NaN
#
#                                            Threat Actor  CAL Score  \
# 5                                                   NaN        640
# 7                                                   NaN        180
# 8                                                   NaN        470
# 10    Emissary Panda, Judgment Panda, UNC6337/STORM-...        180
# 11                                                  NaN        180
# ...                                                 ...        ...
# 1401                                                NaN        170
# 1402                                                NaN        160
# 1403                                                NaN        180
# 1404                                            UNC5837        170
# 1405                                                NaN        170
#
#       ThreatConnect Score  HTOC Threat Score Severity  \
# 5                     820                539     high
# 7                     590                199      low
# 8                     614                633     high
# 10                    288                180      low
# 11                    368                199      low
# ...                   ...                ...      ...
# 1401                  335                362   medium
# 1402                  580                199      low
# 1403                  229                199      low
# 1404                  321                199      low
# 1405                  283                 60      low
#
#                                             Explanation
# 5     [2026-03-05] Severity: high. VT score: 6. Top ...
# 7     [2026-03-05] Severity: low. VT score: 3. Top d...
# 8     [2026-03-05] Severity: high. VT score: 15. Top...
# 10    [2026-03-05] Severity: low. VT score: 2. Top d...
# 11    [2026-03-05] Severity: low. VT score: 1. Top d...
# ...                                                 ...
# 1401  [2026-03-05] Severity: medium. VT score: 5. To...
# 1402  [2026-03-05] Severity: low. VT score: 0. Top d...
# 1403  [2026-03-05] Severity: low. VT score: 2. Top d...
# 1404  [2026-03-05] Severity: low. VT score: 2. Top d...
# 1405  [2026-03-05] Severity: low. VT score not avail...
#
# [869 rows x 16 columns]

# %%
# Filter last 24h results to indicators seen at more than one partner
last_24h_multiple_partners = last_24h_from_max[last_24h_from_max['Partners'].str.contains(',', na=False)]

last_24h_multiple_partners
# Out:
#                                Indicator Last Observed Indicator Type  \
# 5                        103.120.116.162    2026-03-05        Address
# 7                          103.140.62.43    2026-03-04        Address
# 8                          103.143.10.79    2026-03-05        Address
# 10                        103.172.81.132    2026-03-05        Address
# 11                          103.203.59.0    2026-03-05        Address
# ...                                  ...           ...            ...
# 1396              yourpensionmeeting.com    2026-03-05           Host
# 1400                     177.136.225.180    2026-03-05        Address
# 1403                        64.225.66.97    2026-03-05        Address
# 1404                       80.87.206.241    2026-03-05        Address
# 1405  grobinson@blueridgeinfosystems.com    2026-03-04   EmailAddress
#
#       Observation Yearly Count  ThreatConnect Rating  \
# 5                           37                     3
# 7                            6                     5
# 8                            6                     3
# 10                          42                     0
# 11                         271                     3
# ...                        ...                   ...
# 1396                       220                     3
# 1400                         2                     5
# 1403                         2                     2
# 1404                         1                     4
# 1405                         3                     3
#
#       Observation Penalty Multiplier  Botnet Flag  False Positives  \
# 5                           0.997973            0                0
# 7                           0.999671            0                0
# 8                           0.999671            0                0
# 10                          0.997699            0                0
# 11                          0.985151            0                0
# ...                              ...          ...              ...
# 1396                        0.987945            0                0
# 1400                        0.999890            0                0
# 1403                        0.999890            0                0
# 1404                        0.999945            0                0
# 1405                        0.999836            0                0
#
#                                     Partners  \
# 5      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 7                                    DHA, VA
# 8      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 10                    CMS, FDA, HHS, NIH, VA
# 11    CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS
# ...                                      ...
# 1396                       CMS, DHA, NIH, VA
# 1400                        IHS, NIH, OS, VA
# 1403                           CMS, DHA, NIH
# 1404                                CMS, HHS
# 1405              CDC, CMS, FDA, HHS, OS, VA
#
#                                        incidents/events  \
# 5                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 10    Incident:5629499550000872;Incident:56294995470...
# 11                                                  NaN
# ...                                                 ...
# 1396                          Incident:6755399453001053
# 1400                                                NaN
# 1403                             Event:5629499536001088
# 1404                                                NaN
# 1405                                                NaN
#
#                                            Threat Actor  CAL Score  \
# 5                                                   NaN        640
# 7                                                   NaN        180
# 8                                                   NaN        470
# 10    Emissary Panda, Judgment Panda, UNC6337/STORM-...        180
# 11                                                  NaN        180
# ...                                                 ...        ...
# 1396                                                NaN        180
# 1400  Beserk Bear, Cozy Bear, Fancy Bear, Primitive ...        170
# 1403                                                NaN        180
# 1404                                            UNC5837        170
# 1405                                                NaN        170
#
#       ThreatConnect Score  HTOC Threat Score Severity  \
# 5                     820                539     high
# 7                     590                199      low
# 8                     614                633     high
# 10                    288                180      low
# 11                    368                199      low
# ...                   ...                ...      ...
# 1396                  469                360   medium
# 1400                  585                199      low
# 1403                  229                199      low
# 1404                  321                199      low
# 1405                  283                 60      low
#
#                                             Explanation
# 5     [2026-03-05] Severity: high. VT score: 6. Top ...
# 7     [2026-03-05] Severity: low. VT score: 3. Top d...
# 8     [2026-03-05] Severity: high. VT score: 15. Top...
# 10    [2026-03-05] Severity: low. VT score: 2. Top d...
# 11    [2026-03-05] Severity: low. VT score: 1. Top d...
# ...                                                 ...
# 1396  [2026-03-05] Severity: medium. VT score not av...
# 1400  [2026-03-05] Severity: low. VT score: 0. Top d...
# 1403  [2026-03-05] Severity: low. VT score: 2. Top d...
# 1404  [2026-03-05] Severity: low. VT score: 2. Top d...
# 1405  [2026-03-05] Severity: low. VT score not avail...
#
# [856 rows x 16 columns]

# %%
# Filter multi-partner, last-24h indicators to VT score >= 10 based on Explanation text
vt_scores = last_24h_multiple_partners['Explanation'].str.extract(r'VT score:\s*(\d+)', expand=False)
vt_scores = pd.to_numeric(vt_scores, errors='coerce')

last_24h_multi_partners_vt10 = last_24h_multiple_partners[vt_scores >= 10]

last_24h_multi_partners_vt10
