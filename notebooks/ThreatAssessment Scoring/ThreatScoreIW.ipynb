# %%
import pandas as pd

# Load the Excel file
file_path = r"Z:\HTOC\Data_Analytics\Data\Threat Assessment Scores\Threat_Assessment_Scores.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows
df
# Out:
#                Indicator Last Observed Indicator Type  \
# 0            1.234.83.26    2026-02-14        Address
# 1         101.168.57.163    2026-02-14        Address
# 2          101.71.130.99    2026-03-03        Address
# 3         103.114.96.246    2026-02-26        Address
# 4        103.120.116.162    2026-03-16        Address
# ...                  ...           ...            ...
# 2291     198.199.103.243    2026-01-16        Address
# 2292  w-2@doculivery.com    2026-03-04   EmailAddress
# 2293  link.edgepilot.com    2026-03-05           Host
# 2294       52.87.206.242    2026-01-08        Address
# 2295         86.38.243.1    2026-02-04        Address
#
#       Observation Yearly Count  ThreatConnect Rating  \
# 0                           43                     3
# 1                            2                     3
# 2                          139                     3
# 3                           41                     1
# 4                           48                     3
# ...                        ...                   ...
# 2291                         1                     0
# 2292                         2                     4
# 2293                        74                     1
# 2294                         1                     1
# 2295                         8                     4
#
#       Observation Penalty Multiplier  Botnet Flag  False Positives  \
# 0                           0.997644            0                0
# 1                           0.999890            0                0
# 2                           0.992384            0                0
# 3                           0.997753            1                0
# 4                           0.997370            0                0
# ...                              ...          ...              ...
# 2291                        0.999945            1                0
# 2292                        0.999890            1                0
# 2293                        0.995945            0                0
# 2294                        0.999945            1                0
# 2295                        0.999562            0                0
#
#                                     Partners           incidents/events  \
# 0                                        NaN                        NaN
# 1                                        NaN        Incident:INC9407577
# 2     CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS        Incident:INC9270850
# 3                      CMS, DHA, NIH, OS, VA                        NaN
# 4      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA        Incident:INC9385644
# ...                                      ...                        ...
# 2291                                      VA  Incident:6755399478001848
# 2292                                     HHS            Incident:547380
# 2293                                CMS, NIH                        NaN
# 2294                                     IHS                        NaN
# 2295                                 NIH, VA                        NaN
#
#         Threat Actor  CAL Score  ThreatConnect Score  HTOC Threat Score  \
# 0                NaN        180                  469                134
# 1                NaN        180                  590                389
# 2                NaN        180                  346                464
# 3     Mr Hamza Group        170                  224                130
# 4                NaN        740                  870                364
# ...              ...        ...                  ...                ...
# 2291             NaN        180                  368                 41
# 2292             NaN        170                  224                 29
# 2293             NaN        180                  229                 28
# 2294             NaN        170                  224                 27
# 2295             NaN        170                  363                 23
#
#      Severity                                        Explanation
# 0         low  [2026-03-16] Severity: low. VT score: 3. Top d...
# 1      medium  [2026-03-16] Severity: medium. VT score: 11. T...
# 2      medium  [2026-03-16] Severity: medium. VT score: 11. T...
# 3         low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 4      medium  [2026-03-16] Severity: medium. VT score: 6. To...
# ...       ...                                                ...
# 2291      low  Severity: low. VT score: 0. Top drivers: Incid...
# 2292      low  [2026-03-06] Severity: low. VT score not avail...
# 2293      low  [2026-03-06] Severity: low. VT score not avail...
# 2294      low  Severity: low. VT score: 0. Top drivers: TC ra...
# 2295      low  [2026-03-06] Severity: low. VT score: 0. Top d...
#
# [2296 rows x 16 columns]

# %%
import pandas as pd

# Ensure Last Observed is datetime
df['Last Observed'] = pd.to_datetime(df['Last Observed'])

# Get last 24 hours relative to latest observation
max_obs = df['Last Observed'].max()
cutoff = max_obs - pd.Timedelta(days=1)
last_24h_from_max = df[df['Last Observed'] >= cutoff]

last_24h_from_max
# Out:
#                Indicator Last Observed Indicator Type  \
# 4        103.120.116.162    2026-03-16        Address
# 6          103.140.62.43    2026-03-15        Address
# 7          103.143.10.79    2026-03-16        Address
# 9           103.203.59.0    2026-03-16        Address
# 13         103.243.26.49    2026-03-16        Address
# ...                  ...           ...            ...
# 1361        120.71.10.48    2026-03-16        Address
# 1363        134.122.44.7    2026-03-16        Address
# 1366      170.64.230.230    2026-03-16        Address
# 1367     180.167.128.202    2026-03-16        Address
# 1368  link.storjshare.io    2026-03-16           Host
#
#       Observation Yearly Count  ThreatConnect Rating  \
# 4                           48                     3
# 6                           12                     5
# 7                           17                     3
# 9                          282                     3
# 13                          55                     3
# ...                        ...                   ...
# 1361                         2                     5
# 1363                         2                     3
# 1366                         2                     3
# 1367                         5                     3
# 1368                         4                     4
#
#       Observation Penalty Multiplier  Botnet Flag  False Positives  \
# 4                           0.997370            0                0
# 6                           0.999342            0                0
# 7                           0.999068            0                0
# 9                           0.984548            0                0
# 13                          0.996986            0                0
# ...                              ...          ...              ...
# 1361                        0.999890            1                0
# 1363                        0.999890            0                0
# 1366                        0.999890            0                0
# 1367                        0.999726            0                0
# 1368                        0.999781            0                0
#
#                                     Partners     incidents/events  \
# 4      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9385644
# 6                                    DHA, VA                  NaN
# 7      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9426960
# 9     CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS                  NaN
# 13     CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9375302
# ...                                      ...                  ...
# 1361                                     IHS                  NaN
# 1363             CMS, FDA, HRSA, IHS, OS, VA  Incident:INC9411178
# 1366                  CMS, FDA, HRSA, OS, VA  Incident:INC9426249
# 1367  CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS  Incident:INC9444954
# 1368                                IHS, NIH                  NaN
#
#          Threat Actor  CAL Score  ThreatConnect Score  HTOC Threat Score  \
# 4                 NaN        740                  870                364
# 6                 NaN        180                  590                145
# 7                 NaN        770                  764                673
# 9                 NaN        180                  368                 90
# 13                NaN        180                  469                351
# ...               ...        ...                  ...                ...
# 1361              NaN        180                  469                 35
# 1363              NaN        180                  590                410
# 1366              NaN        180                  590                199
# 1367              NaN        180                  590                337
# 1368  Banished Kitten        180                  469                161
#
#      Severity                                        Explanation
# 4      medium  [2026-03-16] Severity: medium. VT score: 6. To...
# 6         low  [2026-03-16] Severity: low. VT score: 3. Top d...
# 7        high  [2026-03-16] Severity: high. VT score: 17. Top...
# 9         low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 13     medium  [2026-03-16] Severity: medium. VT score: 6. To...
# ...       ...                                                ...
# 1361      low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 1363   medium  [2026-03-16] Severity: medium. VT score: 8. To...
# 1366      low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 1367   medium  [2026-03-16] Severity: medium. VT score: 5. To...
# 1368      low  [2026-03-16] Severity: low. VT score not avail...
#
# [837 rows x 16 columns]

# %%
# Filter last 24h results to indicators seen at more than one partner
last_24h_multiple_partners = last_24h_from_max[last_24h_from_max['Partners'].str.contains(',', na=False)]

last_24h_multiple_partners
# Out:
#                Indicator Last Observed Indicator Type  \
# 4        103.120.116.162    2026-03-16        Address
# 6          103.140.62.43    2026-03-15        Address
# 7          103.143.10.79    2026-03-16        Address
# 9           103.203.59.0    2026-03-16        Address
# 13         103.243.26.49    2026-03-16        Address
# ...                  ...           ...            ...
# 1356    www.deepseek.com    2026-03-16           Host
# 1363        134.122.44.7    2026-03-16        Address
# 1366      170.64.230.230    2026-03-16        Address
# 1367     180.167.128.202    2026-03-16        Address
# 1368  link.storjshare.io    2026-03-16           Host
#
#       Observation Yearly Count  ThreatConnect Rating  \
# 4                           48                     3
# 6                           12                     5
# 7                           17                     3
# 9                          282                     3
# 13                          55                     3
# ...                        ...                   ...
# 1356                       346                     3
# 1363                         2                     3
# 1366                         2                     3
# 1367                         5                     3
# 1368                         4                     4
#
#       Observation Penalty Multiplier  Botnet Flag  False Positives  \
# 4                           0.997370            0                0
# 6                           0.999342            0                0
# 7                           0.999068            0                0
# 9                           0.984548            0                0
# 13                          0.996986            0                0
# ...                              ...          ...              ...
# 1356                        0.981041            0                0
# 1363                        0.999890            0                0
# 1366                        0.999890            0                0
# 1367                        0.999726            0                0
# 1368                        0.999781            0                0
#
#                                     Partners     incidents/events  \
# 4      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9385644
# 6                                    DHA, VA                  NaN
# 7      CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9426960
# 9     CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS                  NaN
# 13     CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA  Incident:INC9375302
# ...                                      ...                  ...
# 1356   CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA                  NaN
# 1363             CMS, FDA, HRSA, IHS, OS, VA  Incident:INC9411178
# 1366                  CMS, FDA, HRSA, OS, VA  Incident:INC9426249
# 1367  CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS  Incident:INC9444954
# 1368                                IHS, NIH                  NaN
#
#          Threat Actor  CAL Score  ThreatConnect Score  HTOC Threat Score  \
# 4                 NaN        740                  870                364
# 6                 NaN        180                  590                145
# 7                 NaN        770                  764                673
# 9                 NaN        180                  368                 90
# 13                NaN        180                  469                351
# ...               ...        ...                  ...                ...
# 1356              NaN        180                  469                 50
# 1363              NaN        180                  590                410
# 1366              NaN        180                  590                199
# 1367              NaN        180                  590                337
# 1368  Banished Kitten        180                  469                161
#
#      Severity                                        Explanation
# 4      medium  [2026-03-16] Severity: medium. VT score: 6. To...
# 6         low  [2026-03-16] Severity: low. VT score: 3. Top d...
# 7        high  [2026-03-16] Severity: high. VT score: 17. Top...
# 9         low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 13     medium  [2026-03-16] Severity: medium. VT score: 6. To...
# ...       ...                                                ...
# 1356      low  [2026-03-16] Severity: low. VT score not avail...
# 1363   medium  [2026-03-16] Severity: medium. VT score: 8. To...
# 1366      low  [2026-03-16] Severity: low. VT score: 1. Top d...
# 1367   medium  [2026-03-16] Severity: medium. VT score: 5. To...
# 1368      low  [2026-03-16] Severity: low. VT score not avail...
#
# [826 rows x 16 columns]

# %%
# Filter multi-partner, last-24h indicators to VT score >= 10 based on Explanation text
vt_scores = last_24h_multiple_partners['Explanation'].str.extract(r'VT score:\s*(\d+)', expand=False)
vt_scores = pd.to_numeric(vt_scores, errors='coerce')

last_24h_multi_partners_vt10 = last_24h_multiple_partners[vt_scores >= 10]

last_24h_multi_partners_vt10
# Out:
#            Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 7      103.143.10.79    2026-03-16        Address                        17
# 19    104.152.52.139    2026-03-15        Address                       226
# 20    104.152.52.216    2026-03-15        Address                       223
# 22    104.152.52.237    2026-03-15        Address                       222
# 23    104.152.52.239    2026-03-15        Address                       222
# ...              ...           ...            ...                       ...
# 1243   87.236.176.93    2026-03-15        Address                       268
# 1267    91.224.92.99    2026-03-15        Address                       105
# 1270    92.118.39.95    2026-03-16        Address                       109
# 1278  93.123.109.245    2026-03-15        Address                        23
# 1284   94.16.115.121    2026-03-15        Address                       201
#
#       ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 7                        3                        0.999068            0
# 19                       3                        0.987616            0
# 20                       3                        0.987781            0
# 22                       3                        0.987836            0
# 23                       3                        0.987836            0
# ...                    ...                             ...          ...
# 1243                     3                        0.985315            0
# 1267                     3                        0.994247            0
# 1270                     3                        0.994027            0
# 1278                     3                        0.998740            0
# 1284                     3                        0.988986            0
#
#       False Positives                                    Partners  \
# 7                   0       CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 19                  0            CMS, FDA, HHS, HRSA, NIH, OS, VA
# 20                  0       CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 22                  0       CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 23                  0            CMS, FDA, HHS, HRSA, NIH, OS, VA
# ...               ...                                         ...
# 1243                0       DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1267                0       CMS, DHA, FDA, HHS, HRSA, NIH, OS, VA
# 1270                0  CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 1278                0  CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1284                0            CMS, FDA, HHS, HRSA, IHS, OS, VA
#
#          incidents/events Threat Actor  CAL Score  ThreatConnect Score  \
# 7     Incident:INC9426960          NaN        770                  764
# 19                    NaN          NaN        390                  473
# 20                    NaN          NaN        180                  368
# 22                    NaN          NaN        180                  368
# 23                    NaN          NaN        320                  438
# ...                   ...          ...        ...                  ...
# 1243                  NaN          NaN        410                  483
# 1267                  NaN          NaN        710                  591
# 1270  Incident:INC9310331          NaN        820                  736
# 1278                  NaN          NaN        180                  469
# 1284                  NaN          NaN        220                  517
#
#       HTOC Threat Score Severity  \
# 7                   673     high
# 19                  422   medium
# 20                  499   medium
# 22                  499   medium
# 23                  499   medium
# ...                 ...      ...
# 1243                499   medium
# 1267                499   medium
# 1270                523     high
# 1278                342   medium
# 1284                499   medium
#
#                                             Explanation
# 7     [2026-03-16] Severity: high. VT score: 17. Top...
# 19    [2026-03-16] Severity: medium. VT score: 11. T...
# 20    [2026-03-16] Severity: medium. VT score: 13. T...
# 22    [2026-03-16] Severity: medium. VT score: 13. T...
# 23    [2026-03-16] Severity: medium. VT score: 14. T...
# ...                                                 ...
# 1243  [2026-03-16] Severity: medium. VT score: 15. T...
# 1267  [2026-03-16] Severity: medium. VT score: 14. T...
# 1270  [2026-03-16] Severity: high. VT score: 13. Top...
# 1278  [2026-03-16] Severity: medium. VT score: 10. T...
# 1284  [2026-03-16] Severity: medium. VT score: 13. T...
#
# [476 rows x 16 columns]

# %%
# Keep only high or critical indicators from the VT>=10, multi-partner, last-24h set
high_critical_last_24h = last_24h_multi_partners_vt10[last_24h_multi_partners_vt10['Severity'].isin(['high', 'critical'])]

high_critical_last_24h
# Out:
#             Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 7       103.143.10.79    2026-03-16        Address                        17
# 43       109.70.100.1    2026-03-15        Address                       202
# 44       109.70.100.2    2026-03-15        Address                       206
# 45       109.70.100.5    2026-03-15        Address                       217
# 46       109.70.100.6    2026-03-15        Address                       212
# 51     112.31.180.128    2026-03-16        Address                        15
# 60     121.159.71.249    2026-03-16        Address                       182
# 64      123.58.196.49    2026-03-16        Address                       221
# 65      123.58.207.81    2026-03-16        Address                       215
# 66     123.58.209.112    2026-03-16        Address                       270
# 93       138.59.233.5    2026-03-16        Address                        71
# 95     139.19.117.131    2026-03-16        Address                       159
# 106      141.98.11.82    2026-03-15        Address                        36
# 200    165.154.10.165    2026-03-16        Address                       206
# 201   165.154.173.226    2026-03-16        Address                       180
# 202   165.154.179.204    2026-03-15        Address                       259
# 216    167.94.138.124    2026-03-16        Address                       120
# 261    171.25.193.235    2026-03-15        Address                       218
# 280     176.65.134.22    2026-03-16        Address                        55
# 286     176.65.148.52    2026-03-15        Address                        32
# 317   183.224.237.233    2026-03-16        Address                       176
# 318   184.105.247.252    2026-03-16        Address                        91
# 328    185.156.73.233    2026-03-16        Address                        13
# 344   185.220.101.184    2026-03-15        Address                        35
# 345    185.220.101.21    2026-03-15        Address                       149
# 483    193.32.162.145    2026-03-16        Address                       153
# 532    198.235.24.186    2026-03-16        Address                        88
# 533    198.235.24.193    2026-03-16        Address                        90
# 534    198.235.24.194    2026-03-16        Address                       232
# 574     198.235.24.68    2026-03-16        Address                       232
# 610      2.57.121.112    2026-03-16        Address                        96
# 612       2.57.121.25    2026-03-16        Address                       100
# 629    205.210.31.106    2026-03-16        Address                       232
# 638    205.210.31.163    2026-03-16        Address                        62
# 658    205.210.31.209    2026-03-16        Address                       232
# 666    205.210.31.230    2026-03-16        Address                       232
# 692     205.210.31.66    2026-03-16        Address                       232
# 699     205.210.31.79    2026-03-16        Address                        67
# 749     207.90.244.13    2026-03-16        Address                        90
# 750      207.90.244.3    2026-03-16        Address                        62
# 762   213.209.159.158    2026-03-16        Address                        24
# 779    23.106.248.251    2026-03-15        Address                       181
# 810     37.221.208.71    2026-03-15        Address                       130
# 828    45.132.227.213    2026-03-15        Address                       115
# 848     45.148.10.141    2026-03-16        Address                        55
# 851      45.153.34.87    2026-03-16        Address                        34
# 870     46.161.27.151    2026-03-15        Address                         2
# 903     64.225.74.178    2026-03-16        Address                        43
# 1179       65.49.1.92    2026-03-16        Address                       232
# 1185       65.49.1.99    2026-03-16        Address                       265
# 1199      71.6.232.23    2026-03-16        Address                        60
# 1207   78.128.114.130    2026-03-16        Address                        89
# 1222     80.94.92.171    2026-03-16        Address                       109
# 1229    85.93.218.204    2026-03-15        Address                        38
# 1270     92.118.39.95    2026-03-16        Address                       109
#
#       ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 7                        3                        0.999068            0
# 43                       3                        0.988932            0
# 44                       3                        0.988712            0
# 45                       3                        0.988110            0
# 46                       3                        0.988384            0
# 51                       3                        0.999178            0
# 60                       3                        0.990027            0
# 64                       3                        0.987890            0
# 65                       3                        0.988219            0
# 66                       3                        0.985205            0
# 93                       3                        0.996110            0
# 95                       3                        0.991288            0
# 106                      3                        0.998027            0
# 200                      3                        0.988712            0
# 201                      3                        0.990137            0
# 202                      3                        0.985808            0
# 216                      3                        0.993425            0
# 261                      5                        0.988055            0
# 280                      3                        0.996986            0
# 286                      3                        0.998247            0
# 317                      3                        0.990356            0
# 318                      3                        0.995014            0
# 328                      3                        0.999288            0
# 344                      3                        0.998082            0
# 345                      2                        0.991836            0
# 483                      3                        0.991616            0
# 532                      3                        0.995178            0
# 533                      3                        0.995068            0
# 534                      3                        0.987288            0
# 574                      3                        0.987288            0
# 610                      3                        0.994740            0
# 612                      3                        0.994521            0
# 629                      3                        0.987288            0
# 638                      3                        0.996603            0
# 658                      3                        0.987288            0
# 666                      3                        0.987288            0
# 692                      3                        0.987288            0
# 699                      3                        0.996329            0
# 749                      3                        0.995068            0
# 750                      3                        0.996603            0
# 762                      3                        0.998685            0
# 779                      5                        0.990082            0
# 810                      3                        0.992877            0
# 828                      5                        0.993699            0
# 848                      4                        0.996986            0
# 851                      3                        0.998137            0
# 870                      4                        0.999890            0
# 903                      3                        0.997644            0
# 1179                     3                        0.987288            0
# 1185                     3                        0.985479            0
# 1199                     3                        0.996712            0
# 1207                     3                        0.995123            0
# 1222                     3                        0.994027            0
# 1229                     5                        0.997918            0
# 1270                     3                        0.994027            0
#
#       False Positives                                         Partners  \
# 7                   0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 43                  0                 CMS, FDA, HHS, HRSA, IHS, OS, VA
# 44                  0                 CMS, FDA, HHS, HRSA, IHS, OS, VA
# 45                  0                 CMS, FDA, HHS, HRSA, IHS, OS, VA
# 46                  0                 CMS, FDA, HHS, HRSA, IHS, OS, VA
# 51                  0                          CMS, FDA, HRSA, NIH, OS
# 60                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 64                  0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 65                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 66                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 93                  0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 95                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 106                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 200                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 201                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 202                 0      CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS
# 216                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 261                 0            CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 280                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 286                 0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 317                 0                CMS, FDA, HHS, HRSA, IHS, NIH, OS
# 318                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 328                 0                                          NIH, OS
# 344                 0                 CDC, CMS, FDA, HHS, HRSA, OS, VA
# 345                 0            CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 483                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 532                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 533                 0       CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 534                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 574                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 610                 0                                           OS, VA
# 612                 0                                           OS, VA
# 629                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 638                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 658                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 666                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 692                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 699                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 749                 0                                FDA, HRSA, OS, VA
# 750                 0                           FDA, HRSA, NIH, OS, VA
# 762                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 779                 0        CDC, CMS, DHA, FDA, HHS, IHS, NIH, OS, VA
# 810                 0            CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 828                 0                 CMS, DHA, FDA, HHS, HRSA, OS, VA
# 848                 0                                          HHS, OS
# 851                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 870                 0                                         CMS, HHS
# 903                 0                           FDA, HRSA, NIH, OS, VA
# 1179                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1185                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1199                0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 1207                0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 1222                0       CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 1229                0                 CMS, FDA, HHS, HRSA, IHS, OS, VA
# 1270                0       CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
#
#                              incidents/events  \
# 7                         Incident:INC9426960
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 51                  Incident:6755399484001244
# 60                        Incident:INC9223440
# 64                        Incident:INC9176144
# 65                        Incident:INC9185304
# 66                        Incident:INC9102471
# 93                        Incident:INC9346798
# 95                        Incident:INC9267413
# 106                                       NaN
# 200                       Incident:INC9203759
# 201                       Incident:INC9235915
# 202                       Incident:INC9118016
# 216                                       NaN
# 261                                       NaN
# 280                       Incident:INC9375302
# 286                                       NaN
# 317                           Incident:547382
# 318                       Incident:INC9332624
# 328   Incident:INC9373125;Incident:INC9373119
# 344                                       NaN
# 345                           Incident:102309
# 483                       Incident:INC9263763
# 532                       Incident:INC9341092
# 533                       Incident:INC9337221
# 534                                       NaN
# 574                                       NaN
# 610                       Incident:INC9307742
# 612                       Incident:INC9307742
# 629                       Incident:INC9388679
# 638                       Incident:INC9366814
# 658                                       NaN
# 666                                       NaN
# 692                                       NaN
# 699                                       NaN
# 749                       Incident:INC9337221
# 750                       Incident:INC9366814
# 762                       Incident:INC9411178
# 779                                       NaN
# 810                                       NaN
# 828                                       NaN
# 848                                       NaN
# 851                       Incident:INC9366814
# 870                                       NaN
# 903                       Incident:INC9391086
# 1179                                      NaN
# 1185                                      NaN
# 1199                      Incident:INC9332642
# 1207                      Incident:INC9332642
# 1222                      Incident:INC9303503
# 1229                                      NaN
# 1270                      Incident:INC9310331
#
#                                        Threat Actor  CAL Score  \
# 7                                               NaN        770
# 43                                              NaN        230
# 44                                              NaN        200
# 45                                              NaN        220
# 46                                              NaN        220
# 51                                              NaN        180
# 60                                              NaN        670
# 64                                              NaN        390
# 65                                              NaN        380
# 66                                              NaN        290
# 93                                              NaN        540
# 95                                              NaN        790
# 106                                             NaN        720
# 200                                             NaN        390
# 201                                             NaN        380
# 202                                             NaN        620
# 216                                             NaN        700
# 261          Fancy Bear, Seashell Blizzard, UNC4487        210
# 280                                             NaN        730
# 286                                             NaN        180
# 317                                             NaN        780
# 318                                             NaN        290
# 328                                             NaN        570
# 344                                             NaN        200
# 345                                             NaN        370
# 483                                             NaN        810
# 532                                             NaN        580
# 533                                             NaN        180
# 534                                             NaN        180
# 574                                             NaN        510
# 610                                             NaN        700
# 612                                             NaN        710
# 629                                             NaN        180
# 638                                             NaN        240
# 658                                             NaN        180
# 666                                             NaN        180
# 692                                             NaN        180
# 699                                             NaN        180
# 749                                             NaN        640
# 750                                             NaN        700
# 762                                             NaN        820
# 779                                Scattered Spider        180
# 810                                             NaN        190
# 828                                Scattered Spider        180
# 848   Crimson Collective, Scattered Spider, UNC6395        690
# 851                                             NaN        180
# 870                                 ShadowSyndicate        860
# 903                                             NaN        410
# 1179                                            NaN        180
# 1185                                            NaN        180
# 1199                                            NaN        230
# 1207                                            NaN        490
# 1222                                            NaN        820
# 1229                                           FIN4        200
# 1270                                            NaN        820
#
#       ThreatConnect Score  HTOC Threat Score  Severity  \
# 7                     764                673      high
# 43                    393                552      high
# 44                    479                572      high
# 45                    388                551      high
# 46                    411                572      high
# 51                    399                523      high
# 60                    661                538      high
# 64                    444                531      high
# 65                    439                619      high
# 66                    367                506      high
# 93                    600                626      high
# 95                    721                650      high
# 106                   596                501      high
# 200                   444                571      high
# 201                   439                602      high
# 202                   532                582      high
# 216                   693                536      high
# 261                   356                578      high
# 280                   744                727      high
# 286                   387                524      high
# 317                   699                583      high
# 318                   471                551      high
# 328                   664                539      high
# 344                   443                668      high
# 345                   511                711      high
# 483                   784                583      high
# 532                   616                606      high
# 533                   326                536      high
# 534                   288                504      high
# 574                   453                511      high
# 610                   693                628      high
# 612                   698                628      high
# 629                   368                512      high
# 638                   398                599      high
# 658                   288                504      high
# 666                   368                505      high
# 692                   312                504      high
# 699                   368                506      high
# 749                   598                597      high
# 750                   611                582      high
# 762                   789                693      high
# 779                   590                638      high
# 810                   474                512      high
# 828                   469                720      high
# 848                   671                820  critical
# 851                   590                571      high
# 870                   708                675      high
# 903                   584                597      high
# 1179                  416                505      high
# 1185                  416                504      high
# 1199                  458                537      high
# 1207                  588                520      high
# 1222                  789                603      high
# 1229                  600                684      high
# 1270                  736                523      high
#
#                                             Explanation
# 7     [2026-03-16] Severity: high. VT score: 17. Top...
# 43    [2026-03-16] Severity: high. VT score: 12. Top...
# 44    [2026-03-16] Severity: high. VT score: 13. Top...
# 45    [2026-03-16] Severity: high. VT score: 12. Top...
# 46    [2026-03-16] Severity: high. VT score: 13. Top...
# 51    [2026-03-16] Severity: high. VT score: 14. Top...
# 60    [2026-03-16] Severity: high. VT score: 14. Top...
# 64    [2026-03-16] Severity: high. VT score: 12. Top...
# 65    [2026-03-16] Severity: high. VT score: 15. Top...
# 66    [2026-03-16] Severity: high. VT score: 11. Top...
# 93    [2026-03-16] Severity: high. VT score: 15. Top...
# 95    [2026-03-16] Severity: high. VT score: 16. Top...
# 106   [2026-03-16] Severity: high. VT score: 14. Top...
# 200   [2026-03-16] Severity: high. VT score: 14. Top...
# 201   [2026-03-16] Severity: high. VT score: 14. Top...
# 202   [2026-03-16] Severity: high. VT score: 13. Top...
# 216   [2026-03-16] Severity: high. VT score: 16. Top...
# 261   [2026-03-16] Severity: high. VT score: 16. Top...
# 280   [2026-03-16] Severity: high. VT score: 20. Top...
# 286   [2026-03-16] Severity: high. VT score: 19. Top...
# 317   [2026-03-16] Severity: high. VT score: 14. Top...
# 318   [2026-03-16] Severity: high. VT score: 15. Top...
# 328   [2026-03-16] Severity: high. VT score: 15. Top...
# 344   [2026-03-16] Severity: high. VT score: 14. Top...
# 345   [2026-03-16] Severity: high. VT score: 14. Top...
# 483   [2026-03-16] Severity: high. VT score: 16. Top...
# 532   [2026-03-16] Severity: high. VT score: 14. Top...
# 533   [2026-03-16] Severity: high. VT score: 11. Top...
# 534   [2026-03-16] Severity: high. VT score: 15. Top...
# 574   [2026-03-16] Severity: high. VT score: 15. Top...
# 610   [2026-03-16] Severity: high. VT score: 16. Top...
# 612   [2026-03-16] Severity: high. VT score: 16. Top...
# 629   [2026-03-16] Severity: high. VT score: 10. Top...
# 638   [2026-03-16] Severity: high. VT score: 14. Top...
# 658   [2026-03-16] Severity: high. VT score: 15. Top...
# 666   [2026-03-16] Severity: high. VT score: 15. Top...
# 692   [2026-03-16] Severity: high. VT score: 15. Top...
# 699   [2026-03-16] Severity: high. VT score: 15. Top...
# 749   [2026-03-16] Severity: high. VT score: 14. Top...
# 750   [2026-03-16] Severity: high. VT score: 13. Top...
# 762   [2026-03-16] Severity: high. VT score: 18. Top...
# 779   [2026-03-16] Severity: high. VT score: 10. Top...
# 810   [2026-03-16] Severity: high. VT score: 10. Top...
# 828   [2026-03-16] Severity: high. VT score: 10. Top...
# 848   [2026-03-16] Severity: critical. VT score: 15....
# 851   [2026-03-16] Severity: high. VT score: 16. Top...
# 870   [2026-03-16] Severity: high. VT score: 17. Top...
# 903   [2026-03-16] Severity: high. VT score: 14. Top...
# 1179  [2026-03-16] Severity: high. VT score: 15. Top...
# 1185  [2026-03-16] Severity: high. VT score: 15. Top...
# 1199  [2026-03-16] Severity: high. VT score: 11. Top...
# 1207  [2026-03-16] Severity: high. VT score: 10. Top...
# 1222  [2026-03-16] Severity: high. VT score: 17. Top...
# 1229  [2026-03-16] Severity: high. VT score: 12. Top...
# 1270  [2026-03-16] Severity: high. VT score: 13. Top...

# %%
high_critical_last_24h[high_critical_last_24h['Indicator'] == '45.148.10.141']
# Out:
#          Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 848  45.148.10.141    2026-03-16        Address                        55
#
#      ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 848                     4                        0.996986            0
#
#      False Positives Partners incidents/events  \
# 848                0  HHS, OS              NaN
#
#                                       Threat Actor  CAL Score  \
# 848  Crimson Collective, Scattered Spider, UNC6395        690
#
#      ThreatConnect Score  HTOC Threat Score  Severity  \
# 848                  671                820  critical
#
#                                            Explanation
# 848  [2026-03-16] Severity: critical. VT score: 15....

# %%
# Extract VT scores for high/critical last-24h indicators
vt_scores_hc = high_critical_last_24h['Explanation'].str.extract(r'VT score:\s*(\d+)', expand=False)

# VT-based selection only: keep high/critical last-24h indicators with VT score > 15
vt = pd.to_numeric(vt_scores_hc, errors='coerce')
mask_vt = vt >= 15

final_indicators = high_critical_last_24h[mask_vt]
final_indicators
# Out:
#             Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 7       103.143.10.79    2026-03-16        Address                        17
# 65      123.58.207.81    2026-03-16        Address                       215
# 93       138.59.233.5    2026-03-16        Address                        71
# 95     139.19.117.131    2026-03-16        Address                       159
# 216    167.94.138.124    2026-03-16        Address                       120
# 261    171.25.193.235    2026-03-15        Address                       218
# 280     176.65.134.22    2026-03-16        Address                        55
# 286     176.65.148.52    2026-03-15        Address                        32
# 318   184.105.247.252    2026-03-16        Address                        91
# 328    185.156.73.233    2026-03-16        Address                        13
# 483    193.32.162.145    2026-03-16        Address                       153
# 534    198.235.24.194    2026-03-16        Address                       232
# 574     198.235.24.68    2026-03-16        Address                       232
# 610      2.57.121.112    2026-03-16        Address                        96
# 612       2.57.121.25    2026-03-16        Address                       100
# 658    205.210.31.209    2026-03-16        Address                       232
# 666    205.210.31.230    2026-03-16        Address                       232
# 692     205.210.31.66    2026-03-16        Address                       232
# 699     205.210.31.79    2026-03-16        Address                        67
# 762   213.209.159.158    2026-03-16        Address                        24
# 848     45.148.10.141    2026-03-16        Address                        55
# 851      45.153.34.87    2026-03-16        Address                        34
# 870     46.161.27.151    2026-03-15        Address                         2
# 1179       65.49.1.92    2026-03-16        Address                       232
# 1185       65.49.1.99    2026-03-16        Address                       265
# 1222     80.94.92.171    2026-03-16        Address                       109
#
#       ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 7                        3                        0.999068            0
# 65                       3                        0.988219            0
# 93                       3                        0.996110            0
# 95                       3                        0.991288            0
# 216                      3                        0.993425            0
# 261                      5                        0.988055            0
# 280                      3                        0.996986            0
# 286                      3                        0.998247            0
# 318                      3                        0.995014            0
# 328                      3                        0.999288            0
# 483                      3                        0.991616            0
# 534                      3                        0.987288            0
# 574                      3                        0.987288            0
# 610                      3                        0.994740            0
# 612                      3                        0.994521            0
# 658                      3                        0.987288            0
# 666                      3                        0.987288            0
# 692                      3                        0.987288            0
# 699                      3                        0.996329            0
# 762                      3                        0.998685            0
# 848                      4                        0.996986            0
# 851                      3                        0.998137            0
# 870                      4                        0.999890            0
# 1179                     3                        0.987288            0
# 1185                     3                        0.985479            0
# 1222                     3                        0.994027            0
#
#       False Positives                                         Partners  \
# 7                   0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 65                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 93                  0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 95                  0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 216                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 261                 0            CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 280                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 286                 0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 318                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 328                 0                                          NIH, OS
# 483                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 534                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 574                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 610                 0                                           OS, VA
# 612                 0                                           OS, VA
# 658                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 666                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 692                 0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 699                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 762                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 848                 0                                          HHS, OS
# 851                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 870                 0                                         CMS, HHS
# 1179                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1185                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 1222                0       CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
#
#                              incidents/events  \
# 7                         Incident:INC9426960
# 65                        Incident:INC9185304
# 93                        Incident:INC9346798
# 95                        Incident:INC9267413
# 216                                       NaN
# 261                                       NaN
# 280                       Incident:INC9375302
# 286                                       NaN
# 318                       Incident:INC9332624
# 328   Incident:INC9373125;Incident:INC9373119
# 483                       Incident:INC9263763
# 534                                       NaN
# 574                                       NaN
# 610                       Incident:INC9307742
# 612                       Incident:INC9307742
# 658                                       NaN
# 666                                       NaN
# 692                                       NaN
# 699                                       NaN
# 762                       Incident:INC9411178
# 848                                       NaN
# 851                       Incident:INC9366814
# 870                                       NaN
# 1179                                      NaN
# 1185                                      NaN
# 1222                      Incident:INC9303503
#
#                                        Threat Actor  CAL Score  \
# 7                                               NaN        770
# 65                                              NaN        380
# 93                                              NaN        540
# 95                                              NaN        790
# 216                                             NaN        700
# 261          Fancy Bear, Seashell Blizzard, UNC4487        210
# 280                                             NaN        730
# 286                                             NaN        180
# 318                                             NaN        290
# 328                                             NaN        570
# 483                                             NaN        810
# 534                                             NaN        180
# 574                                             NaN        510
# 610                                             NaN        700
# 612                                             NaN        710
# 658                                             NaN        180
# 666                                             NaN        180
# 692                                             NaN        180
# 699                                             NaN        180
# 762                                             NaN        820
# 848   Crimson Collective, Scattered Spider, UNC6395        690
# 851                                             NaN        180
# 870                                 ShadowSyndicate        860
# 1179                                            NaN        180
# 1185                                            NaN        180
# 1222                                            NaN        820
#
#       ThreatConnect Score  HTOC Threat Score  Severity  \
# 7                     764                673      high
# 65                    439                619      high
# 93                    600                626      high
# 95                    721                650      high
# 216                   693                536      high
# 261                   356                578      high
# 280                   744                727      high
# 286                   387                524      high
# 318                   471                551      high
# 328                   664                539      high
# 483                   784                583      high
# 534                   288                504      high
# 574                   453                511      high
# 610                   693                628      high
# 612                   698                628      high
# 658                   288                504      high
# 666                   368                505      high
# 692                   312                504      high
# 699                   368                506      high
# 762                   789                693      high
# 848                   671                820  critical
# 851                   590                571      high
# 870                   708                675      high
# 1179                  416                505      high
# 1185                  416                504      high
# 1222                  789                603      high
#
#                                             Explanation
# 7     [2026-03-16] Severity: high. VT score: 17. Top...
# 65    [2026-03-16] Severity: high. VT score: 15. Top...
# 93    [2026-03-16] Severity: high. VT score: 15. Top...
# 95    [2026-03-16] Severity: high. VT score: 16. Top...
# 216   [2026-03-16] Severity: high. VT score: 16. Top...
# 261   [2026-03-16] Severity: high. VT score: 16. Top...
# 280   [2026-03-16] Severity: high. VT score: 20. Top...
# 286   [2026-03-16] Severity: high. VT score: 19. Top...
# 318   [2026-03-16] Severity: high. VT score: 15. Top...
# 328   [2026-03-16] Severity: high. VT score: 15. Top...
# 483   [2026-03-16] Severity: high. VT score: 16. Top...
# 534   [2026-03-16] Severity: high. VT score: 15. Top...
# 574   [2026-03-16] Severity: high. VT score: 15. Top...
# 610   [2026-03-16] Severity: high. VT score: 16. Top...
# 612   [2026-03-16] Severity: high. VT score: 16. Top...
# 658   [2026-03-16] Severity: high. VT score: 15. Top...
# 666   [2026-03-16] Severity: high. VT score: 15. Top...
# 692   [2026-03-16] Severity: high. VT score: 15. Top...
# 699   [2026-03-16] Severity: high. VT score: 15. Top...
# 762   [2026-03-16] Severity: high. VT score: 18. Top...
# 848   [2026-03-16] Severity: critical. VT score: 15....
# 851   [2026-03-16] Severity: high. VT score: 16. Top...
# 870   [2026-03-16] Severity: high. VT score: 17. Top...
# 1179  [2026-03-16] Severity: high. VT score: 15. Top...
# 1185  [2026-03-16] Severity: high. VT score: 15. Top...
# 1222  [2026-03-16] Severity: high. VT score: 17. Top...

# %%
import sys
import os
import urllib3
from configparser import ConfigParser

# Add your local ThreatConnect SDK to path
sys.path.append(r"Z:\HTOC\Data_Analytics\threatconnect")
from ThreatConnect import ThreatConnect
from RequestObject import RequestObject
from Owners import Owners

# Add your project repo to path
project_root = r"C:\Users\jaskew\Documents\project_repository\scripts\Data Movement\ThrearConnect-api-pull"
if project_root not in sys.path:
    sys.path.append(project_root)

from utils.config_loader import load_config

# Load API config
config_path = os.path.join(project_root, "utils", "config.json")
try:
    api_secret_key, api_access_id, api_base_url, api_default_org = load_config(config_path)
    display(f"Loaded config from: {config_path}")
    display(f"Base URL: {api_base_url}")
    display(f"Access ID: {api_access_id}")
    display(f"Default Org: {api_default_org}")
except Exception as e:
    display(f"[ERROR] Failed to load configuration: {e}")
    sys.exit(1)

# Disable SSL verification warnings (use cautiously)
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
verify_ssl = False

# Initialize ThreatConnect session
try:
    tc = ThreatConnect(api_access_id, api_secret_key, api_default_org, api_base_url)
    display("ThreatConnect initialized.")
except Exception as e:
    display(f"[ERROR] Failed to initialize ThreatConnect: {e}")
    sys.exit(1)

# Define the owner (organization scope)
owner = 'HTOC Org'

# Create a request object to fetch indicators (or other data)
try:
    ro = RequestObject()
    ro.set_http_method('GET')
    ro.set_owner(owner)
    ro.set_owner_allowed(True)
    # ro.set_resource_pagination(True)  # Uncomment if needed
    display("RequestObject successfully created.")
except Exception as e:
    display(f"[ERROR] Failed to initialize RequestObject: {e}")
    sys.exit(1)
# Out:
# 'Loaded config from: C:\\Users\\jaskew\\Documents\\project_repository\\scripts\\Data Movement\\ThrearConnect-api-pull\\utils\\config.json'
# 'Base URL: https://hvs.threatconnect.com/api'
# 'Access ID: 09783848890162390382'
# 'Default Org: HTOC Org'
# 'ThreatConnect initialized.'
# 'RequestObject successfully created.'

# %%
import pandas as pd
from datetime import datetime, timedelta
import pytz
import urllib.parse

# Configuration for ThreatConnect indicator query
QUERY_LOOKBACK_DAYS = 30  # days of lastObserved activity to include
INDICATOR_TYPE_NAMES = [
    "Address", "EmailAddress", "File", "Host", "URL", "ASN", "CIDR",
    "Email Subject", "Hashtag", "Mutex", "Registry Key", "User Agent",
]
OWNER_NAMES = [
    'HTOC Org',
    'CISA Federal Feed',
    'CMS_CTI',
    'Crowdstrike Falcon Intelligence',
    'DHS CISCP',
    'Intel471',
    'Mandiant Advantage Threat Intelligence',
    'VA_TIP Data',
]
RESULT_PAGE_SIZE = 500  # keep this smaller; same fields, just paged
INDICATOR_CHUNK_SIZE = 100  # limit size of summary IN (...) clauses

# Setup
cutoff = pd.Timestamp.utcnow()
start_date = (datetime.now(pytz.UTC) - timedelta(days=QUERY_LOOKBACK_DAYS)).date()
start = f"{start_date}T00:00:00Z"

type_names = INDICATOR_TYPE_NAMES
type_name_condition = ", ".join([f'"{t}"' for t in type_names])

list_of_owners = OWNER_NAMES

# Build owner IN (...) clause
owner_condition = ", ".join([f'"{o}"' for o in list_of_owners])

# Build indicator list from final_indicators (must already exist)
if 'final_indicators' not in globals():
    raise RuntimeError("final_indicators is not defined. Run the scoring cell first.")

if 'Indicator' not in final_indicators.columns:
    raise RuntimeError("final_indicators must have an 'Indicator' column.")

indicator_values = (
    final_indicators['Indicator']
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

if not indicator_values:
    raise RuntimeError("final_indicators has no Indicator values to query.")

# Chunk indicators so the TQL summary IN (...) clause and URL don't get too large
indicator_chunks = [
    indicator_values[i:i + INDICATOR_CHUNK_SIZE]
    for i in range(0, len(indicator_values), INDICATOR_CHUNK_SIZE)
]

final_results = []

# Query indicators (paginate so you don't 502 with heavy fields)
# Create a NEW RequestObject WITHOUT owner restriction to query across all owners
ro_multi = RequestObject()
ro_multi.set_http_method('GET')

for chunk in indicator_chunks:
    # Build summary IN ("x","y",...) clause for this chunk
    summary_condition = ", ".join([f'"{v}"' for v in chunk])

    tql_raw = (
        f'ownerName IN ({owner_condition}) AND '
        f'typeName IN ({type_name_condition}) AND '
        f'lastObserved >= "{start}" AND '
        f'summary IN ({summary_condition})'
    )

    tql_encoded = urllib.parse.quote(tql_raw)

    result_start = 0
    result_limit = RESULT_PAGE_SIZE

    while True:
        try:
            # NOTE: same fields list you requested (tags,observations,associatedGroups,falsePositives,threatAssess)
            ro_multi.set_request_uri(
                f'/v3/indicators?tql={tql_encoded}'
                f'&fields=tags,observations,associatedGroups,falsePositives,threatAssess'
                f'&resultStart={result_start}&resultLimit={result_limit}'
            )

            response = tc.api_request(ro_multi)

            ct = response.headers.get('content-type', '')
            if not ct.startswith('application/json'):
                raise RuntimeError(f"Non-JSON response ({ct}): {response.content[:200]}")

            results = response.json()
            data_items = results.get('data', []) or []

            # stop when no more results
            if not data_items:
                break

            final_results.append(results)
            result_start += result_limit

        except Exception as e:
            display(f"Failed to query indicators (chunk size={len(chunk)}, start={result_start}): {e}")
            break

# Normalize results
normalized_data = []
for result in final_results:
    data_items = result.get('data', [])
    if not data_items:
        display("No data returned in API response:", result)
    for item in data_items:
        if isinstance(item, dict) and 'summary' in item:
            normalized_data.append(item)

if normalized_data:
    observed_src = pd.json_normalize(normalized_data)
    observed_src['indicator'] = observed_src['summary'].astype(str).str.split().str[0].str.strip()
    observed_src['lastObserved'] = pd.to_datetime(observed_src['lastObserved'], utc=True, errors='coerce')
    observed_src = observed_src[observed_src['lastObserved'] >= pd.to_datetime(start, utc=True)]

    # Create a 'sources' column by aggregating ownerName values per indicator
    sources_per_indicator = (
        observed_src.groupby('indicator')['ownerName']
        .apply(lambda x: ', '.join(sorted(set(x))))
        .reset_index()
        .rename(columns={'ownerName': 'sources'})
    )

    # Merge sources back into observed_src
    observed_src = observed_src.merge(sources_per_indicator, on='indicator', how='left')
    # Filter to keep only records where ownerName is 'HTOC Org'
    observed_src = observed_src[observed_src['ownerName'] == 'HTOC Org'].copy()
else:
    display("No valid indicator data found.")
    observed_src = pd.DataFrame()

display(observed_src)
# Out:
#                   id             dateAdded  ownerId ownerName  \
# 0   5629499561376171  2025-07-28T17:15:37Z        9  HTOC Org
# 1   5629499578154891  2025-11-25T18:08:21Z        9  HTOC Org
# 2   6755399482008641  2025-11-21T16:32:42Z        9  HTOC Org
# 3   6755399475098423  2025-10-09T12:44:59Z        9  HTOC Org
# 4   5629499588124309  2026-02-17T20:34:32Z        9  HTOC Org
# 8   5629499574100045  2025-10-22T17:52:34Z        9  HTOC Org
# 11  6755399465229522  2025-07-28T17:34:08Z        9  HTOC Org
# 12  5629499584034451  2026-01-20T19:44:18Z        9  HTOC Org
# 13  6755399481063961  2025-11-17T16:08:16Z        9  HTOC Org
# 14  5629499578154887  2025-11-25T18:08:18Z        9  HTOC Org
# 15  5629499570118108  2025-10-02T17:13:20Z        9  HTOC Org
# 17  6755399494008118  2026-02-28T17:40:37Z        9  HTOC Org
# 20  6755399467058891  2025-08-08T14:21:47Z        9  HTOC Org
# 21  5629499582019974  2025-12-29T14:35:07Z        9  HTOC Org
# 22  5629499581012209  2025-12-15T16:04:41Z        9  HTOC Org
# 25  5629499584035050  2026-01-21T14:28:00Z        9  HTOC Org
# 26  5629499547737364  2025-06-04T16:43:17Z        9  HTOC Org
# 29  5629499536037128  2025-04-14T16:04:29Z        9  HTOC Org
# 30  6755399487004193  2026-01-14T14:12:02Z        9  HTOC Org
# 32           4406762  2023-09-26T18:36:47Z        9  HTOC Org
# 33  6755399465229527  2025-07-28T17:34:12Z        9  HTOC Org
# 35  6755399459078588  2025-06-25T17:34:59Z        9  HTOC Org
# 37  6755399465229332  2025-07-28T17:15:57Z        9  HTOC Org
# 38  6755399465229335  2025-07-28T17:15:59Z        9  HTOC Org
# 39  5629499561376901  2025-07-28T17:34:11Z        9  HTOC Org
# 43  6755399487000241  2026-01-09T15:39:13Z        9  HTOC Org
#
#                                               webLink     type  \
# 0   https://hvs.threatconnect.com/#/details/indica...  Address
# 1   https://hvs.threatconnect.com/#/details/indica...  Address
# 2   https://hvs.threatconnect.com/#/details/indica...  Address
# 3   https://hvs.threatconnect.com/#/details/indica...  Address
# 4   https://hvs.threatconnect.com/#/details/indica...  Address
# 8   https://hvs.threatconnect.com/#/details/indica...  Address
# 11  https://hvs.threatconnect.com/#/details/indica...  Address
# 12  https://hvs.threatconnect.com/#/details/indica...  Address
# 13  https://hvs.threatconnect.com/#/details/indica...  Address
# 14  https://hvs.threatconnect.com/#/details/indica...  Address
# 15  https://hvs.threatconnect.com/#/details/indica...  Address
# 17  https://hvs.threatconnect.com/#/details/indica...  Address
# 20  https://hvs.threatconnect.com/#/details/indica...  Address
# 21  https://hvs.threatconnect.com/#/details/indica...  Address
# 22  https://hvs.threatconnect.com/#/details/indica...  Address
# 25  https://hvs.threatconnect.com/#/details/indica...  Address
# 26  https://hvs.threatconnect.com/#/details/indica...  Address
# 29  https://hvs.threatconnect.com/#/details/indica...  Address
# 30  https://hvs.threatconnect.com/#/details/indica...  Address
# 32  https://hvs.threatconnect.com/#/details/indica...  Address
# 33  https://hvs.threatconnect.com/#/details/indica...  Address
# 35  https://hvs.threatconnect.com/#/details/indica...  Address
# 37  https://hvs.threatconnect.com/#/details/indica...  Address
# 38  https://hvs.threatconnect.com/#/details/indica...  Address
# 39  https://hvs.threatconnect.com/#/details/indica...  Address
# 43  https://hvs.threatconnect.com/#/details/indica...  Address
#
#             lastModified  rating  confidence  threatAssessRating  ...  \
# 0   2026-03-16T13:22:31Z     3.0        48.0                1.50  ...
# 1   2026-03-16T13:22:28Z     3.0        66.0                2.00  ...
# 2   2026-03-16T13:22:23Z     3.0        64.0                3.00  ...
# 3   2026-03-16T11:22:21Z     3.0        59.0                1.50  ...
# 4   2026-03-16T11:22:21Z     3.0        78.0                1.50  ...
# 8   2026-03-16T10:06:01Z     4.0        65.0                2.00  ...
# 11  2026-03-16T09:22:16Z     3.0        71.0                1.50  ...
# 12  2026-03-16T09:22:15Z     3.0        73.0                2.00  ...
# 13  2026-03-16T09:22:13Z     3.0        65.0                2.00  ...
# 14  2026-03-16T09:22:12Z     3.0        66.0                2.00  ...
# 15  2026-03-16T09:22:12Z     3.0        57.0                3.00  ...
# 17  2026-03-16T09:01:01Z     3.0        80.0                1.50  ...
# 20  2026-03-16T09:01:01Z     3.0        50.0                1.00  ...
# 21  2026-03-16T09:01:01Z     3.0        71.0                2.65  ...
# 22  2026-03-16T09:01:01Z     3.0        69.0                2.50  ...
# 25  2026-03-16T00:24:38Z     3.0        73.0                1.50  ...
# 26  2026-03-16T00:07:17Z     3.0        41.0                2.00  ...
# 29  2026-03-15T23:23:16Z     5.0        56.0                2.47  ...
# 30  2026-03-15T09:22:18Z     3.0        73.0                3.00  ...
# 32  2026-03-15T07:06:01Z     4.0        48.0                1.60  ...
# 33  2026-03-14T00:24:26Z     3.0        50.0                1.50  ...
# 35  2026-03-14T00:06:49Z     3.0        50.0                1.50  ...
# 37  2026-03-13T00:23:53Z     3.0        48.0                1.00  ...
# 38  2026-03-11T09:23:23Z     3.0        48.0                1.50  ...
# 39  2026-03-11T09:23:16Z     3.0        48.0                1.50  ...
# 43  2026-03-10T09:22:02Z     3.0        72.0                1.50  ...
#
#     privateFlag  active  activeLocked               ip  \
# 0         False    True         False    198.235.24.68
# 1         False    True         False     2.57.121.112
# 2         False    True         False     80.94.92.171
# 3         False    True         False   139.19.117.131
# 4         False    True         False  213.209.159.158
# 8         False    True         False    45.148.10.141
# 11        False    True         False   205.210.31.230
# 12        False    True         False   185.156.73.233
# 13        False    True         False   167.94.138.124
# 14        False    True         False      2.57.121.25
# 15        False    True         False   193.32.162.145
# 17        False    True         False    103.143.10.79
# 20        False    True         False    123.58.207.81
# 21        False    True         False     138.59.233.5
# 22        False    True         False  184.105.247.252
# 25        False    True         False    176.65.134.22
# 26        False    True         False    176.65.148.52
# 29        False    True         False   171.25.193.235
# 30        False    True         False     45.153.34.87
# 32        False    True         False    46.161.27.151
# 33        False    True         False       65.49.1.92
# 35        False    True         False       65.49.1.99
# 37        False    True         False    205.210.31.66
# 38        False    True         False   205.210.31.209
# 39        False    True         False   198.235.24.194
# 43        False    True         False    205.210.31.79
#
#                                            legacyLink  \
# 0   https://hvs.threatconnect.com/auth/indicators/...
# 1   https://hvs.threatconnect.com/auth/indicators/...
# 2   https://hvs.threatconnect.com/auth/indicators/...
# 3   https://hvs.threatconnect.com/auth/indicators/...
# 4   https://hvs.threatconnect.com/auth/indicators/...
# 8   https://hvs.threatconnect.com/auth/indicators/...
# 11  https://hvs.threatconnect.com/auth/indicators/...
# 12  https://hvs.threatconnect.com/auth/indicators/...
# 13  https://hvs.threatconnect.com/auth/indicators/...
# 14  https://hvs.threatconnect.com/auth/indicators/...
# 15  https://hvs.threatconnect.com/auth/indicators/...
# 17  https://hvs.threatconnect.com/auth/indicators/...
# 20  https://hvs.threatconnect.com/auth/indicators/...
# 21  https://hvs.threatconnect.com/auth/indicators/...
# 22  https://hvs.threatconnect.com/auth/indicators/...
# 25  https://hvs.threatconnect.com/auth/indicators/...
# 26  https://hvs.threatconnect.com/auth/indicators/...
# 29  https://hvs.threatconnect.com/auth/indicators/...
# 30  https://hvs.threatconnect.com/auth/indicators/...
# 32  https://hvs.threatconnect.com/auth/indicators/...
# 33  https://hvs.threatconnect.com/auth/indicators/...
# 35  https://hvs.threatconnect.com/auth/indicators/...
# 37  https://hvs.threatconnect.com/auth/indicators/...
# 38  https://hvs.threatconnect.com/auth/indicators/...
# 39  https://hvs.threatconnect.com/auth/indicators/...
# 43  https://hvs.threatconnect.com/auth/indicators/...
#
#                                             tags.data source  \
# 0   [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 1   [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 2   [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 3   [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 4   [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 8   [{'id': 1739892, 'name': 'UNC6395', 'lastUsed'...    NaN
# 11  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 12  [{'id': 35760, 'name': 'OS Splunk API', 'descr...    NaN
# 13  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 14  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 15  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 17  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 20  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 21  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 22  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 25  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 26  [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 29  [{'id': 494361, 'name': 'UNC4487', 'lastUsed':...    NaN
# 30  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 32  [{'id': 258988, 'name': 'Amber Members', 'last...    NaN
# 33  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
# 35  [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 37  [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 38  [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 39  [{'id': 471298, 'name': 'DHA Splunk API', 'las...    NaN
# 43  [{'id': 2023876, 'name': 'VA OIT CSOC CTS Splu...    NaN
#
#                                 associatedGroups.data        indicator  \
# 0                                                 NaN    198.235.24.68
# 1                                                 NaN     2.57.121.112
# 2                                                 NaN     80.94.92.171
# 3                                                 NaN   139.19.117.131
# 4                                                 NaN  213.209.159.158
# 8   [{'id': 6755399479000167, 'dateAdded': '2026-0...    45.148.10.141
# 11                                                NaN   205.210.31.230
# 12                                                NaN   185.156.73.233
# 13                                                NaN   167.94.138.124
# 14                                                NaN      2.57.121.25
# 15                                                NaN   193.32.162.145
# 17                                                NaN    103.143.10.79
# 20                                                NaN    123.58.207.81
# 21                                                NaN     138.59.233.5
# 22                                                NaN  184.105.247.252
# 25                                                NaN    176.65.134.22
# 26                                                NaN    176.65.148.52
# 29  [{'id': 6755399448000753, 'dateAdded': '2025-0...   171.25.193.235
# 30                                                NaN     45.153.34.87
# 32  [{'id': 5629499546000858, 'dateAdded': '2025-0...    46.161.27.151
# 33                                                NaN       65.49.1.92
# 35                                                NaN       65.49.1.99
# 37                                                NaN    205.210.31.66
# 38                                                NaN   205.210.31.209
# 39                                                NaN   198.235.24.194
# 43                                                NaN    205.210.31.79
#
#                         sources
# 0           DHS CISCP, HTOC Org
# 1   CISA Federal Feed, HTOC Org
# 2                      HTOC Org
# 3           DHS CISCP, HTOC Org
# 4   CISA Federal Feed, HTOC Org
# 8             CMS_CTI, HTOC Org
# 11          DHS CISCP, HTOC Org
# 12                     HTOC Org
# 13          DHS CISCP, HTOC Org
# 14  CISA Federal Feed, HTOC Org
# 15                     HTOC Org
# 17  CISA Federal Feed, HTOC Org
# 20          DHS CISCP, HTOC Org
# 21  CISA Federal Feed, HTOC Org
# 22                     HTOC Org
# 25  CISA Federal Feed, HTOC Org
# 26                     HTOC Org
# 29                     HTOC Org
# 30                     HTOC Org
# 32            CMS_CTI, HTOC Org
# 33          DHS CISCP, HTOC Org
# 35          DHS CISCP, HTOC Org
# 37          DHS CISCP, HTOC Org
# 38          DHS CISCP, HTOC Org
# 39          DHS CISCP, HTOC Org
# 43          DHS CISCP, HTOC Org
#
# [26 rows x 31 columns]

# %%
import pandas as pd

# Helper to see if an indicator has an I&W tag
def has_iw(tags_value):
    """
    tags_value is typically a list of dicts from ThreatConnect, e.g.:
    [{'name': 'I&W'}, {'name': 'something else'}, ...]
    """
    if tags_value is None or (isinstance(tags_value, float) and pd.isna(tags_value)):
        return False

    if not isinstance(tags_value, (list, tuple)):
        return False

    for t in tags_value:
        try:
            if isinstance(t, dict):
                name = str(t.get('name', '')).strip()
            else:
                name = str(t).strip()

            if name.lower() in {"i&w", "i & w", "iw"}:
                return True
        except Exception:
            continue
    return False

# 1) Add has_iw flag to observed_src if tags.data exists
if 'tags.data' in observed_src.columns:
    observed_src['has_iw'] = observed_src['tags.data'].apply(has_iw)
else:
    observed_src['has_iw'] = False

# 2) Collapse to one flag per indicator
iw_per_indicator = (
    observed_src.groupby('indicator', dropna=False)['has_iw']
    .max()  # any True -> True
    .reset_index()
    .rename(columns={'indicator': 'Indicator', 'has_iw': 'Reported I&W?_raw'})
)

# 3) Drop ANY existing Reported I&W? variants (_x, _y, etc.)
cols_to_drop = [c for c in final_indicators.columns if c.startswith('Reported I&W?')]
final_indicators = final_indicators.drop(columns=cols_to_drop, errors='ignore')

# 4) Merge once, with a temporary raw boolean column
final_indicators = final_indicators.merge(
    iw_per_indicator,
    on='Indicator',
    how='left'
)

# 5) Convert to Yes/No, defaulting missing to 'No'
final_indicators['Reported I&W?'] = (
    final_indicators['Reported I&W?_raw']
    .fillna(False)
    .map({True: 'Yes', False: 'No'})
)

# 6) Drop the temporary raw column
final_indicators = final_indicators.drop(columns=['Reported I&W?_raw'])

final_indicators
# Out:
#           Indicator Last Observed Indicator Type  Observation Yearly Count  \
# 0     103.143.10.79    2026-03-16        Address                        17
# 1     123.58.207.81    2026-03-16        Address                       215
# 2      138.59.233.5    2026-03-16        Address                        71
# 3    139.19.117.131    2026-03-16        Address                       159
# 4    167.94.138.124    2026-03-16        Address                       120
# 5    171.25.193.235    2026-03-15        Address                       218
# 6     176.65.134.22    2026-03-16        Address                        55
# 7     176.65.148.52    2026-03-15        Address                        32
# 8   184.105.247.252    2026-03-16        Address                        91
# 9    185.156.73.233    2026-03-16        Address                        13
# 10   193.32.162.145    2026-03-16        Address                       153
# 11   198.235.24.194    2026-03-16        Address                       232
# 12    198.235.24.68    2026-03-16        Address                       232
# 13     2.57.121.112    2026-03-16        Address                        96
# 14      2.57.121.25    2026-03-16        Address                       100
# 15   205.210.31.209    2026-03-16        Address                       232
# 16   205.210.31.230    2026-03-16        Address                       232
# 17    205.210.31.66    2026-03-16        Address                       232
# 18    205.210.31.79    2026-03-16        Address                        67
# 19  213.209.159.158    2026-03-16        Address                        24
# 20    45.148.10.141    2026-03-16        Address                        55
# 21     45.153.34.87    2026-03-16        Address                        34
# 22    46.161.27.151    2026-03-15        Address                         2
# 23       65.49.1.92    2026-03-16        Address                       232
# 24       65.49.1.99    2026-03-16        Address                       265
# 25     80.94.92.171    2026-03-16        Address                       109
#
#     ThreatConnect Rating  Observation Penalty Multiplier  Botnet Flag  \
# 0                      3                        0.999068            0
# 1                      3                        0.988219            0
# 2                      3                        0.996110            0
# 3                      3                        0.991288            0
# 4                      3                        0.993425            0
# 5                      5                        0.988055            0
# 6                      3                        0.996986            0
# 7                      3                        0.998247            0
# 8                      3                        0.995014            0
# 9                      3                        0.999288            0
# 10                     3                        0.991616            0
# 11                     3                        0.987288            0
# 12                     3                        0.987288            0
# 13                     3                        0.994740            0
# 14                     3                        0.994521            0
# 15                     3                        0.987288            0
# 16                     3                        0.987288            0
# 17                     3                        0.987288            0
# 18                     3                        0.996329            0
# 19                     3                        0.998685            0
# 20                     4                        0.996986            0
# 21                     3                        0.998137            0
# 22                     4                        0.999890            0
# 23                     3                        0.987288            0
# 24                     3                        0.985479            0
# 25                     3                        0.994027            0
#
#     False Positives                                         Partners  \
# 0                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 1                 0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 2                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 3                 0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 4                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 5                 0            CMS, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 6                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 7                 0       CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 8                 0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 9                 0                                          NIH, OS
# 10                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 11                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 12                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 13                0                                           OS, VA
# 14                0                                           OS, VA
# 15                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 16                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 17                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 18                0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 19                0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 20                0                                          HHS, OS
# 21                0            CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
# 22                0                                         CMS, HHS
# 23                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 24                0  CDC, CMS, DHA, FDA, HHS, HRSA, IHS, NIH, OS, VA
# 25                0       CDC, CMS, DHA, FDA, HRSA, IHS, NIH, OS, VA
#
#                            incidents/events  \
# 0                       Incident:INC9426960
# 1                       Incident:INC9185304
# 2                       Incident:INC9346798
# 3                       Incident:INC9267413
# 4                                       NaN
# 5                                       NaN
# 6                       Incident:INC9375302
# 7                                       NaN
# 8                       Incident:INC9332624
# 9   Incident:INC9373125;Incident:INC9373119
# 10                      Incident:INC9263763
# 11                                      NaN
# 12                                      NaN
# 13                      Incident:INC9307742
# 14                      Incident:INC9307742
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                      Incident:INC9411178
# 20                                      NaN
# 21                      Incident:INC9366814
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                      Incident:INC9303503
#
#                                      Threat Actor  CAL Score  \
# 0                                             NaN        770
# 1                                             NaN        380
# 2                                             NaN        540
# 3                                             NaN        790
# 4                                             NaN        700
# 5          Fancy Bear, Seashell Blizzard, UNC4487        210
# 6                                             NaN        730
# 7                                             NaN        180
# 8                                             NaN        290
# 9                                             NaN        570
# 10                                            NaN        810
# 11                                            NaN        180
# 12                                            NaN        510
# 13                                            NaN        700
# 14                                            NaN        710
# 15                                            NaN        180
# 16                                            NaN        180
# 17                                            NaN        180
# 18                                            NaN        180
# 19                                            NaN        820
# 20  Crimson Collective, Scattered Spider, UNC6395        690
# 21                                            NaN        180
# 22                                ShadowSyndicate        860
# 23                                            NaN        180
# 24                                            NaN        180
# 25                                            NaN        820
#
#     ThreatConnect Score  HTOC Threat Score  Severity  \
# 0                   764                673      high
# 1                   439                619      high
# 2                   600                626      high
# 3                   721                650      high
# 4                   693                536      high
# 5                   356                578      high
# 6                   744                727      high
# 7                   387                524      high
# 8                   471                551      high
# 9                   664                539      high
# 10                  784                583      high
# 11                  288                504      high
# 12                  453                511      high
# 13                  693                628      high
# 14                  698                628      high
# 15                  288                504      high
# 16                  368                505      high
# 17                  312                504      high
# 18                  368                506      high
# 19                  789                693      high
# 20                  671                820  critical
# 21                  590                571      high
# 22                  708                675      high
# 23                  416                505      high
# 24                  416                504      high
# 25                  789                603      high
#
#                                           Explanation Reported I&W?
# 0   [2026-03-16] Severity: high. VT score: 17. Top...            No
# 1   [2026-03-16] Severity: high. VT score: 15. Top...            No
# 2   [2026-03-16] Severity: high. VT score: 15. Top...            No
# 3   [2026-03-16] Severity: high. VT score: 16. Top...            No
# 4   [2026-03-16] Severity: high. VT score: 16. Top...            No
# 5   [2026-03-16] Severity: high. VT score: 16. Top...           Yes
# 6   [2026-03-16] Severity: high. VT score: 20. Top...            No
# 7   [2026-03-16] Severity: high. VT score: 19. Top...            No
# 8   [2026-03-16] Severity: high. VT score: 15. Top...            No
# 9   [2026-03-16] Severity: high. VT score: 15. Top...            No
# 10  [2026-03-16] Severity: high. VT score: 16. Top...            No
# 11  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 12  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 13  [2026-03-16] Severity: high. VT score: 16. Top...            No
# 14  [2026-03-16] Severity: high. VT score: 16. Top...            No
# 15  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 16  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 17  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 18  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 19  [2026-03-16] Severity: high. VT score: 18. Top...            No
# 20  [2026-03-16] Severity: critical. VT score: 15....           Yes
# 21  [2026-03-16] Severity: high. VT score: 16. Top...            No
# 22  [2026-03-16] Severity: high. VT score: 17. Top...            No
# 23  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 24  [2026-03-16] Severity: high. VT score: 15. Top...            No
# 25  [2026-03-16] Severity: high. VT score: 17. Top...            No

# %% [markdown]
# from datetime import datetime
#
# # Build dated output path
# today_str = datetime.today().strftime('%Y%m%d')  # e.g. 20260316
# output_path = rf"Z:\HTOC\Data_Analytics\Data\Threat Assessment Scores\ThreatAssessI_W\ThreatAssessI_W_{today_str}.xlsx"
#
# # Write to Excel
# final_indicators.to_excel(output_path, index=False)
#
# output_path
