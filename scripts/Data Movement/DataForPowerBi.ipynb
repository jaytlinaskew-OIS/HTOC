# %%
import shutil
import os

# Define source and destination paths
source_file = r"C:\Users\jaskew\Documents\project_repository\data\processed\ProcessedObservedData.csv"
destination_folder = r"C:\Users\jaskew\PowerBi\Data\ObservationData"

# Ensure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Define the destination file path
destination_file = os.path.join(destination_folder, os.path.basename(source_file))

# Copy the file
shutil.copy(source_file, destination_file)

print(f"File successfully exported to {destination_file}")
# Out:
# File successfully exported to C:\Users\jaskew\PowerBi\Data\ObservationData\ProcessedObservedData.csv
