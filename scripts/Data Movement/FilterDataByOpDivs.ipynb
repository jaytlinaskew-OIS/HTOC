# %%
import pandas as pd

# %%
#grab all data from C:\Users\jaskew\Documents\project_repository\data\processed\ProcessedObservedData.csv
df = pd.read_csv(r"C:\Users\jaskew\Documents\project_repository\data\processed\ProcessedObservedData.csv", index_col=0, parse_dates=True)
df.tail(10)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\3733076487.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(r"C:\Users\jaskew\Documents\project_repository\data\processed\ProcessedObservedData.csv", index_col=0, parse_dates=True)
#                                             API_UserName    obs_date OpDiv  \
# indicator
# page.24supportkit.com               74198686107399967946  2025-05-29    VA
# 192.200.148.241                     74198686107399967946  2025-05-29    VA
# 216.131.120.91                      74198686107399967946  2025-05-29    VA
# 92.60.40.210                        13983566077459384977  2025-05-29   FDA
# 74.208.236.241                      74198686107399967946  2025-05-29    VA
# 207.244.71.82                       64853912235916233429  2025-05-29    OS
# ...

# %%
#If CMS, filter by OpDive and save to C:\Users\jaskew\Documents\project_repository\data\processed\CMS.csv
# Check what's in CMS.csv and make sure we don't save duplicate records
existing_cms = pd.read_csv(r"C:\Users\jaskew\Documents\project_repository\data\processed\CMS.csv", index_col=0, parse_dates=True)
df_cms = df[df['OpDiv'] == 'CMS']

# Remove duplicates based on all columns
df_cms = pd.concat([existing_cms, df_cms]).drop_duplicates()

# Save the updated dataframe back to CMS.csv
df_cms.to_csv(r"C:\Users\jaskew\Documents\project_repository\data\processed\CMS.csv")
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\3199914914.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_cms = pd.read_csv(r"C:\Users\jaskew\Documents\project_repository\data\processed\CMS.csv", index_col=0, parse_dates=True)

# %%
# If CDC, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\CDC.csv
# Check what's in CDC.csv and make sure we don't save duplicate records
import os

# Check if the file exists and is not empty
cdc_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\CDC.csv"
if os.path.exists(cdc_file_path) and os.path.getsize(cdc_file_path) > 0:
	existing_cdc = pd.read_csv(cdc_file_path, index_col=0, parse_dates=True)
else:
	# Initialize an empty DataFrame with the same columns as df
	existing_cdc = pd.DataFrame(columns=df.columns)

df_cdc = df[df['OpDiv'] == 'CDC']

# Remove duplicates based on all columns
df_cdc = pd.concat([existing_cdc, df_cdc]).drop_duplicates()

# Save the updated dataframe back to CDC.csv
df_cdc.to_csv(cdc_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\1272377142.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_cdc = pd.read_csv(cdc_file_path, index_col=0, parse_dates=True)

# %%
# If DHA, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\DHA.csv
# Check what's in DHA.csv and make sure we don't save duplicate records
dha_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\DHA.csv"

# Check if the file exists and is not empty
if os.path.exists(dha_file_path) and os.path.getsize(dha_file_path) > 0:
    existing_dha = pd.read_csv(dha_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_dha = pd.DataFrame(columns=df.columns)

df_dha = df[df['OpDiv'] == 'DHA']

# Remove duplicates based on all columns
df_dha = pd.concat([existing_dha, df_dha]).drop_duplicates()

# Save the updated dataframe back to DHA.csv
df_dha.to_csv(dha_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\1657015326.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_dha = pd.read_csv(dha_file_path, index_col=0, parse_dates=True)

# %%
# If FDA, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\FDA.csv
# Check what's in FDA.csv and make sure we don't save duplicate records
fda_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\FDA.csv"

# Check if the file exists and is not empty
if os.path.exists(fda_file_path) and os.path.getsize(fda_file_path) > 0:
    existing_fda = pd.read_csv(fda_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_fda = pd.DataFrame(columns=df.columns)

df_fda = df[df['OpDiv'] == 'FDA']

# Remove duplicates based on all columns
df_fda = pd.concat([existing_fda, df_fda]).drop_duplicates()

# Save the updated dataframe back to FDA.csv
df_fda.to_csv(fda_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\4185847771.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_fda = pd.read_csv(fda_file_path, index_col=0, parse_dates=True)

# %%
# If HHS, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\HHS.csv
# Check what's in HHS.csv and make sure we don't save duplicate records
hhs_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\HHS.csv"

# Check if the file exists and is not empty
if os.path.exists(hhs_file_path) and os.path.getsize(hhs_file_path) > 0:
    existing_hhs = pd.read_csv(hhs_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_hhs = pd.DataFrame(columns=df.columns)

df_hhs = df[df['OpDiv'] == 'HHS']

# Remove duplicates based on all columns
df_hhs = pd.concat([existing_hhs, df_hhs]).drop_duplicates()

# Save the updated dataframe back to HHS.csv
df_hhs.to_csv(hhs_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\2736473524.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_hhs = pd.read_csv(hhs_file_path, index_col=0, parse_dates=True)

# %%
# If HRSA, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\HRSA.csv
# Check what's in HRSA.csv and make sure we don't save duplicate records
hrsa_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\HRSA.csv"

# Check if the file exists and is not empty
if os.path.exists(hrsa_file_path) and os.path.getsize(hrsa_file_path) > 0:
    existing_hrsa = pd.read_csv(hrsa_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_hrsa = pd.DataFrame(columns=df.columns)

df_hrsa = df[df['OpDiv'] == 'HRSA']

# Remove duplicates based on all columns
df_hrsa = pd.concat([existing_hrsa, df_hrsa]).drop_duplicates()

# Save the updated dataframe back to HRSA.csv
df_hrsa.to_csv(hrsa_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\1697055594.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_hrsa = pd.read_csv(hrsa_file_path, index_col=0, parse_dates=True)

# %%
# If IHS, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\IHS.csv
# Check what's in IHS.csv and make sure we don't save duplicate records
ihs_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\IHS.csv"

# Check if the file exists and is not empty
if os.path.exists(ihs_file_path) and os.path.getsize(ihs_file_path) > 0:
    existing_ihs = pd.read_csv(ihs_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_ihs = pd.DataFrame(columns=df.columns)

df_ihs = df[df['OpDiv'] == 'IHS']

# Remove duplicates based on all columns
df_ihs = pd.concat([existing_ihs, df_ihs]).drop_duplicates()

# Save the updated dataframe back to IHS.csv
df_ihs.to_csv(ihs_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\1554717584.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_ihs = pd.read_csv(ihs_file_path, index_col=0, parse_dates=True)

# %%
# If OS, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\OS.csv
# Check what's in OS.csv and make sure we don't save duplicate records
os_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\OS.csv"

# Check if the file exists and is not empty
if os.path.exists(os_file_path) and os.path.getsize(os_file_path) > 0:
    existing_os = pd.read_csv(os_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_os = pd.DataFrame(columns=df.columns)

df_os = df[df['OpDiv'] == 'OS']

# Remove duplicates based on all columns
df_os = pd.concat([existing_os, df_os]).drop_duplicates()

# Save the updated dataframe back to OS.csv
df_os.to_csv(os_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\4042677973.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_os = pd.read_csv(os_file_path, index_col=0, parse_dates=True)

# %%
# If VA, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\VA.csv
# Check what's in VA.csv and make sure we don't save duplicate records
va_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\VA.csv"

# Check if the file exists and is not empty
if os.path.exists(va_file_path) and os.path.getsize(va_file_path) > 0:
    existing_va = pd.read_csv(va_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_va = pd.DataFrame(columns=df.columns)

df_va = df[df['OpDiv'] == 'VA']

# Remove duplicates based on all columns
df_va = pd.concat([existing_va, df_va]).drop_duplicates()

# Save the updated dataframe back to VA.csv
df_va.to_csv(va_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\4088731396.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_va = pd.read_csv(va_file_path, index_col=0, parse_dates=True)

# %%
# If NIH, filter by OpDiv and save to C:\Users\jaskew\Documents\project_repository\data\processed\VA.csv
# Check what's in VA.csv and make sure we don't save duplicate records
nih_file_path = r"C:\Users\jaskew\Documents\project_repository\data\processed\NIH.csv"

# Check if the file exists and is not empty
if os.path.exists(nih_file_path) and os.path.getsize(nih_file_path) > 0:
    existing_va = pd.read_csv(nih_file_path, index_col=0, parse_dates=True)
else:
    # Initialize an empty DataFrame with the same columns as df
    existing_va = pd.DataFrame(columns=df.columns)

df_nih = df[df['OpDiv'] == 'NIH']

# Remove duplicates based on all columns
df_nih = pd.concat([existing_va, df_nih]).drop_duplicates()

# Save the updated dataframe back to VA.csv
df_nih.to_csv(nih_file_path)
# Out:
# C:\Users\jaskew\AppData\Local\Temp\ipykernel_11168\186980827.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   existing_va = pd.read_csv(nih_file_path, index_col=0, parse_dates=True)
